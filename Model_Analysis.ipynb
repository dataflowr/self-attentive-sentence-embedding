# %% [markdown]
# # Model analysis and heat map

# %%
import numpy as np
import torch
import json
import spacy
from prettytable import PrettyTable
import os
import sys
import yaml
from yaml import Loader
from util import Dictionary
from torch import nn
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from train import package

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for token in doc:
    print(token.text, token.pos_, token.dep_, token.vector_norm)# token.vector
# Out:
# Apple PROPN nsubj 7.9169617
# is AUX aux 8.597497
# looking VERB ROOT 8.68382
# at ADP prep 7.737509
# buying VERB pcomp 9.099992
# U.K. PROPN dobj 7.7217307
# startup NOUN advcl 5.9194016
# for ADP prep 7.6531463
# $ SYM quantmod 9.727607
# 1 NUM compound 10.960313
# billion NUM pobj 8.402847

# %% [markdown]
# ## Download our models:

# %% [markdown]
# #### Git lfs is used to store our models, therefore we must install it:

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %% [markdown]
# #### If you do not have a file named models, it downloads ours:

# %%
models_exists = os.path.exists("models/")
if(not models_exists):
    #!mkdir model_test
    #%cd model_test
    # !git clone https://github.com/Learningchipmunk/models.git
else:
    print("You already have models of your own !")
# Out:
# You already have models of your own !

# %% [markdown]
# ## Count the model parameters:

# %%
def count_parameters(model):
    """Function that prints a the summary table of a network. 
        It also counts how many parameters require gradient.

    Args:
        model (nn.Module): A neural network with multiple paramters requiring gradient.

    Returns:
        int: Returns the total number of parameters that requires gradient. 
    """
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
            
        ## Splitting the name into processable data:
        l        = name.split(".")

        Net_name = l[0]
        fun      = l[1]
        
                    
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
model_bestval = torch.load("models/test.pkl")

# %%
model_bestval.parameters
# Out:
# <bound method Module.parameters of Classifier(
#   (encoder): SelfAttentiveEncoder(
#     (bilstm): BiLSTM(
#       (drop): Dropout(p=0.5, inplace=False)
#       (encoder): Embedding(28199, 200)
#       (bilstm): LSTM(200, 300, num_layers=2, dropout=0.5, bidirectional=True)
#     )
#     (drop): Dropout(p=0.5, inplace=False)
#     (ws1): Linear(in_features=600, out_features=350, bias=False)
#     (ws2): Linear(in_features=350, out_features=4, bias=False)
#     (tanh): Tanh()
#     (softmax): Softmax(dim=1)
#   )
#   (fc): Linear(in_features=2400, out_features=300, bias=True)
#   (drop): Dropout(p=0.5, inplace=False)
#   (tanh): Tanh()
#   (pred): Linear(in_features=300, out_features=5, bias=True)
# )>

# %%
count_parameters(model_bestval)
# Out:
# +--------------------------------------------+------------+
# |                  Modules                   | Parameters |
# +--------------------------------------------+------------+
# |       encoder.bilstm.encoder.weight        |  5639800   |
# |     encoder.bilstm.bilstm.weight_ih_l0     |   240000   |
# |     encoder.bilstm.bilstm.weight_hh_l0     |   360000   |
# |      encoder.bilstm.bilstm.bias_ih_l0      |    1200    |
# |      encoder.bilstm.bilstm.bias_hh_l0      |    1200    |
# | encoder.bilstm.bilstm.weight_ih_l0_reverse |   240000   |
# | encoder.bilstm.bilstm.weight_hh_l0_reverse |   360000   |
# |  encoder.bilstm.bilstm.bias_ih_l0_reverse  |    1200    |
# |  encoder.bilstm.bilstm.bias_hh_l0_reverse  |    1200    |
# |     encoder.bilstm.bilstm.weight_ih_l1     |   720000   |
# |     encoder.bilstm.bilstm.weight_hh_l1     |   360000   |
# |      encoder.bilstm.bilstm.bias_ih_l1      |    1200    |
# |      encoder.bilstm.bilstm.bias_hh_l1      |    1200    |
# | encoder.bilstm.bilstm.weight_ih_l1_reverse |   720000   |
# | encoder.bilstm.bilstm.weight_hh_l1_reverse |   360000   |
# |  encoder.bilstm.bilstm.bias_ih_l1_reverse  |    1200    |
# |  encoder.bilstm.bilstm.bias_hh_l1_reverse  |    1200    |
# |             encoder.ws1.weight             |   210000   |
# |             encoder.ws2.weight             |    1400    |
# |                 fc.weight                  |   720000   |
# |                  fc.bias                   |    300     |
# |                pred.weight                 |    1500    |
# |                 pred.bias                  |     5      |
# +--------------------------------------------+------------+
# Total Trainable Params: 9942605
# 9942605

# %%
model_bestacc = torch.load("models/test..best_acc.pt")

# %%
model_bestacc.parameters
# Out:
# <bound method Module.parameters of Classifier(
#   (encoder): SelfAttentiveEncoder(
#     (bilstm): BiLSTM(
#       (drop): Dropout(p=0.5, inplace=False)
#       (encoder): Embedding(28199, 200)
#       (bilstm): LSTM(200, 300, num_layers=2, dropout=0.5, bidirectional=True)
#     )
#     (drop): Dropout(p=0.5, inplace=False)
#     (ws1): Linear(in_features=600, out_features=350, bias=False)
#     (ws2): Linear(in_features=350, out_features=4, bias=False)
#     (tanh): Tanh()
#     (softmax): Softmax(dim=1)
#   )
#   (fc): Linear(in_features=2400, out_features=300, bias=True)
#   (drop): Dropout(p=0.5, inplace=False)
#   (tanh): Tanh()
#   (pred): Linear(in_features=300, out_features=5, bias=True)
# )>

# %% [markdown]
# ## Fetching the data and the sentiment matrix attached to it:

# %% [markdown]
# #### getting the config file with the data paths:

# %%
with open("config_small.yaml", "r") as ymlfile:
    cfg = yaml.load(ymlfile, Loader= Loader)

cfg
# Out:
# {'cuda': True,
#  'seed': 1111,
#  'class_number': 5,
#  'model': {'emsize': 200,
#   'nhid': 300,
#   'nlayers': 2,
#   'pooling': 'all',
#   'attention_unit': 350,
#   'attention_hops': 4,
#   'dropout': 0.5,
#   'clip': 0.5,
#   'nfc': 300},
#  'training': {'lr': 0.001,
#   'optimizer': 'Adam',
#   'scheduler': {'using_scheduler': True,
#    'name': 'ReduceLROnPlateau',
#    'factor': 0.5,
#    'patience': 1,
#    'step_size': 1},
#   'epochs': 20,
#   'log_interval': 20,
#   'batch_size': 50,
#   'penalization_coeff': 1},
#  'data': {'save': '/Data/pls_do_not_delete/Project-self-attentive-sentence-embedding/models/with_sched3.pkl',
#   'dictionary': '/Data/pls_do_not_delete/Project-self-attentive-sentence-embedding/small/dict_review_short.json',
#   'word_vector': '/Data/pls_do_not_delete/Project-self-attentive-sentence-embedding/content/glove.6B.200d.txt.pt',
#   'train_data': '/Data/pls_do_not_delete/Project-self-attentive-sentence-embedding/small/train_tok.json',
#   'val_data': '/Data/pls_do_not_delete/Project-self-attentive-sentence-embedding/small/val_tok.json',
#   'test_data': '/Data/pls_do_not_delete/Project-self-attentive-sentence-embedding/small/test_tok.json'}}

# %% [markdown]
# #### Downloading the data if not present:

# %%
small_exists = os.path.exists("small/")

if(not small_exists):
    # !wget https://www.di.ens.fr/~lelarge/small_yelp.zip
    # !unzip small_yelp.zip
else:
    print("You already have the data.")
# Out:
# You already have the data.

# %% [markdown]
# #### Loading the data:

# %%
dictionary = dictionary = Dictionary(path=cfg["data"]["dictionary"])

global dictionary

# %%
dictionary.word2idx
# Out:
# {'<pad>': 0,
#  'ok': 1,
#  'if': 2,
#  'you': 3,
#  'are': 4,
#  'looking': 5,
#  'for': 6,
#  'amazing': 7,
#  'home': 8,
#  'cooked': 9,
#  'italian': 10,
#  'food': 11,
#  'in': 12,
#  'the': 13,
#  'valley': 14,
#  'then': 15,
#  'this': 16,
#  'is': 17,
#  'place': 18,
#  'to': 19,
#  'go': 20,
#  '!': 21,
#  'simple': 22,
#  'and': 23,
#  'i': 24,
#  'personally': 25,
#  'love': 26,
#  'eggplant': 27,
#  'with': 28,
#  'noodles': 29,
#  'their': 30,
#  'pizzas': 31,
#  'which': 32,
#  'stunning': 33,
#  'it': 34,
#  "'s": 35,
#  'a': 36,
#  'small': 37,
#  'expect': 38,
#  'wait': 39,
#  'quality': 40,
#  'but': 41,
#  'they': 42,
#  'do': 43,
#  'accept': 44,
#  'phone': 45,
#  'orders': 46,
#  '-': 47,
#  'so': 48,
#  'call': 49,
#  'ahead': 50,
#  "n't": 51,
#  'look': 52,
#  'any': 53,
#  'further': 54,
#  ',': 55,
#  '.': 56,
#  'while': 57,
#  'was': 58,
#  'making': 59,
#  'an': 60,
#  'appointment': 61,
#  'heard': 62,
#  'stefanie': 63,
#  'at': 64,
#  'front': 65,
#  'desk': 66,
#  'on': 67,
#  'patient': 68,
#  'that': 69,
#  'needed': 70,
#  'results': 71,
#  'before': 72,
#  'vacation': 73,
#  'she': 74,
#  'assured': 75,
#  'person': 76,
#  'would': 77,
#  'contact': 78,
#  'proper': 79,
#  'people': 80,
#  'get': 81,
#  'right': 82,
#  'back': 83,
#  'her': 84,
#  '..': 85,
#  'did': 86,
#  'my': 87,
#  'appt': 88,
#  'couple': 89,
#  'of': 90,
#  'annual': 91,
#  'tests': 92,
#  'mammography': 93,
#  'administered': 94,
#  'by': 95,
#  'denise': 96,
#  'great': 97,
#  'asked': 98,
#  'about': 99,
#  '3d': 100,
#  'imaging': 101,
#  'technology': 102,
#  'patiently': 103,
#  'explained': 104,
#  'how': 105,
#  'works': 106,
#  'next': 107,
#  'up': 108,
#  'bone': 109,
#  'density': 110,
#  'erica': 111,
#  'again': 112,
#  'pleasant': 113,
#  'happy': 114,
#  'service': 115,
#  'entire': 116,
#  'visit': 117,
#  'way': 118,
#  'above': 119,
#  'normal': 120,
#  'expectations': 121,
#  'most': 122,
#  'flavorful': 123,
#  'friendly': 124,
#  'staff': 125,
#  'we': 126,
#  'have': 127,
#  'been': 128,
#  'some': 129,
#  'finest': 130,
#  'restaurants': 131,
#  'las': 132,
#  'vegas': 133,
#  'week': 134,
#  'many': 135,
#  'were': 136,
#  'good': 137,
#  'tops': 138,
#  'them': 139,
#  'all': 140,
#  'veggie': 141,
#  'pizza': 142,
#  'fresh': 143,
#  'ingredients': 144,
#  'just': 145,
#  'amount': 146,
#  'chewy': 147,
#  'crispness': 148,
#  'crust': 149,
#  '...': 150,
#  'neighborhood': 151,
#  'center': 152,
#  'coffee': 153,
#  'patio': 154,
#  'year': 155,
#  'long': 156,
#  'came': 157,
#  'bluenose': 158,
#  'stall': 159,
#  'assembly': 160,
#  'hall': 161,
#  'lobster': 162,
#  'after': 163,
#  'drooling': 164,
#  'days': 165,
#  'end': 166,
#  'instagram': 167,
#  'streams': 168,
#  'images': 169,
#  'wish': 170,
#  'rolls': 171,
#  'bigger': 172,
#  'completely': 173,
#  'contained': 174,
#  'two': 175,
#  'hands': 176,
#  'large': 177,
#  'hunks': 178,
#  'meat': 179,
#  'jutting': 180,
#  'out': 181,
#  'buttery': 182,
#  'fragrance': 183,
#  'pervading': 184,
#  'personal': 185,
#  'space': 186,
#  'vanished': 187,
#  'one': 188,
#  'second': 189,
#  'hand': 190,
#  'stomach': 191,
#  'honestly': 192,
#  'though': 193,
#  'expensive': 194,
#  'price': 195,
#  'portion': 196,
#  'ratio': 197,
#  'every': 198,
#  'bit': 199,
#  'as': 200,
#  'delicious': 201,
#  'had': 202,
#  'imagined': 203,
#  ';': 204,
#  'want': 205,
#  'more': 206,
#  'friend': 207,
#  'soup': 208,
#  'our': 209,
#  'likings': 210,
#  "'d": 211,
#  'definitely': 212,
#  'golden': 213,
#  'pheasant': 214,
#  '(': 215,
#  'tgp': 216,
#  ')': 217,
#  '1,277': 218,
#  'miles': 219,
#  '2,055': 220,
#  'km': 221,
#  'canucks': 222,
#  'away': 223,
#  'from': 224,
#  'know': 225,
#  'because': 226,
#  'looked': 227,
#  'what': 228,
#  'when': 229,
#  "'m": 230,
#  'missing': 231,
#  'restaurant': 232,
#  'obsess': 233,
#  'over': 234,
#  'frequently': 235,
#  'mean': 236,
#  'hard': 237,
#  'not': 238,
#  'really': 239,
#  'schnitzel': 240,
#  'words': 241,
#  'ca': 242,
#  'begin': 243,
#  'describe': 244,
#  'much': 245,
#  'everything': 246,
#  'absolutely': 247,
#  'yes': 248,
#  'point': 249,
#  'mother': 250,
#  'pearl': 251,
#  'potato': 252,
#  'salad': 253,
#  'see': 254,
#  'pictures': 255,
#  'under': 256,
#  'stuff': 257,
#  'dreams': 258,
#  'may': 259,
#  'be': 260,
#  'thinking': 261,
#  '"': 262,
#  'guy': 263,
#  'calm': 264,
#  'yourself': 265,
#  'respond': 266,
#  'no': 267,
#  'shut': 268,
#  'your': 269,
#  'stupid': 270,
#  'face': 271,
#  'even': 272,
#  'there': 273,
#  'enough': 274,
#  'can': 275,
#  'share': 276,
#  'serving': 277,
#  'option': 278,
#  'coming': 279,
#  'december': 280,
#  "'re": 281,
#  'third': 282,
#  'stop': 283,
#  'grab': 284,
#  'double': 285,
#  'chilli': 286,
#  'chicken': 287,
#  'house': 288,
#  ':': 289,
#  'insert': 290,
#  'excited': 291,
#  'squealing': 292,
#  'jonah': 293,
#  'hill': 294,
#  'pose': 295,
#  'here': 296,
#  'sam': 297,
#  'irene': 298,
#  'saved': 299,
#  'wedding': 300,
#  'dress': 301,
#  'shopping': 302,
#  'day': 303,
#  'flew': 304,
#  'tennessee': 305,
#  'try': 306,
#  'specific': 307,
#  'meeting': 308,
#  'bridesmaids': 309,
#  'also': 310,
#  'flying': 311,
#  'set': 312,
#  'store': 313,
#  '....': 314,
#  'horrible': 315,
#  'experience': 316,
#  'found': 317,
#  'helped': 318,
#  'me': 319,
#  'loved': 320,
#  'convinced': 321,
#  'pick': 322,
#  'accessories': 323,
#  'extremely': 324,
#  'professional': 325,
#  'helpful': 326,
#  'totally': 327,
#  'salesy': 328,
#  'job': 329,
#  'am': 330,
#  'grateful': 331,
#  'sweet': 332,
#  'personalities': 333,
#  'order': 334,
#  'went': 335,
#  'later': 336,
#  'afternoon': 337,
#  'tried': 338,
#  'ha': 339,
#  'til': 340,
#  'gets': 341,
#  'man': 342,
#  'sees': 343,
#  ':)': 344,
#  'thanks': 345,
#  'rock': 346,
#  'cheesecake': 347,
#  'factory': 348,
#  'make': 349,
#  'lunch': 350,
#  'anytime': 351,
#  'leaving': 352,
#  'charlotte': 353,
#  'columbia': 354,
#  'today': 355,
#  'started': 356,
#  'tuna': 357,
#  'tartare': 358,
#  'beautifully': 359,
#  'presented': 360,
#  'very': 361,
#  'nice': 362,
#  'diversion': 363,
#  'healthy': 364,
#  'appetizers': 365,
#  'ordered': 366,
#  'favorite': 367,
#  'louisiana': 368,
#  'pasta': 369,
#  's.o.': 370,
#  'teriyaki': 371,
#  'both': 372,
#  'excellent': 373,
#  'server': 374,
#  'awesome': 375,
#  'several': 376,
#  'drinks': 377,
#  'corporate': 378,
#  'places': 379,
#  'exception': 380,
#  'rule': 381,
#  "'ve": 382,
#  'wanting': 383,
#  'salon': 384,
#  'still': 385,
#  'hunt': 386,
#  'best': 387,
#  'brazillian': 388,
#  'toronto': 389,
#  'online': 390,
#  'liked': 391,
#  'funny': 392,
#  'casual': 393,
#  'approach': 394,
#  'marketing': 395,
#  'book': 396,
#  'now': 397,
#  'credit': 398,
#  'card': 399,
#  'never': 400,
#  'getting': 401,
#  'time': 402,
#  'soon': 403,
#  'booking': 404,
#  'feature': 405,
#  'need': 406,
#  'secure': 407,
#  'mentioned': 408,
#  'called': 409,
#  'directly': 410,
#  'woman': 411,
#  'said': 412,
#  'part': 413,
#  'cancellation': 414,
#  'policy': 415,
#  'number': 416,
#  'services': 417,
#  'since': 418,
#  'come': 419,
#  'into': 420,
#  'buy': 421,
#  'gift': 422,
#  'value': 423,
#  'basically': 424,
#  'insist': 425,
#  'pay': 426,
#  'those': 427,
#  'rendered': 428,
#  'business': 429,
#  'kidding': 430,
#  '?': 431,
#  'understand': 432,
#  'company': 433,
#  'trying': 434,
#  'ensure': 435,
#  'appointments': 436,
#  'kept': 437,
#  'bringing': 438,
#  'money': 439,
#  'fine': 440,
#  'pretty': 441,
#  'extreme': 442,
#  'seems': 443,
#  'dishonest': 444,
#  'leave': 445,
#  '$': 446,
#  '65': 447,
#  'myself': 448,
#  'wax': 449,
#  'eyelash': 450,
#  'tint': 451,
#  'going': 452,
#  'happen': 453,
#  'boast': 454,
#  'could': 455,
#  'potentially': 456,
#  'frequent': 457,
#  'loyal': 458,
#  'customer': 459,
#  'habit': 460,
#  'handing': 461,
#  'companies': 462,
#  'done': 463,
#  'speak': 464,
#  'someone': 465,
#  'briefly': 466,
#  'lame': 467,
#  'taking': 468,
#  'elsewhere': 469,
#  'sept': 470,
#  '21': 471,
#  '2016': 472,
#  'car': 473,
#  'serviced': 474,
#  'south': 475,
#  'hyundai': 476,
#  'oil': 477,
#  'change': 478,
#  '/': 479,
#  'lube': 480,
#  'left': 481,
#  '224.11': 482,
#  'bill': 483,
#  'refused': 484,
#  'recommended': 485,
#  'wheel': 486,
#  'alignment': 487,
#  'only': 488,
#  'opinion': 489,
#  'unless': 490,
#  'handling': 491,
#  'badly': 492,
#  'or': 493,
#  'notice': 494,
#  'unusual': 495,
#  'tire': 496,
#  'wear': 497,
#  'always': 498,
#  'skip': 499,
#  'costly': 500,
#  'recommendation': 501,
#  'website': 502,
#  'internet': 503,
#  'stated': 504,
#  'takes': 505,
#  'lot': 506,
#  'knock': 507,
#  'average': 508,
#  'run': 509,
#  'mill': 510,
#  'pothole': 511,
#  'wo': 512,
#  'interested': 513,
#  'reading': 514,
#  'article': 515,
#  'find': 516,
#  'http://www.roadandtravel.com/carcare/alignment.html': 517,
#  'fairness': 518,
#  'other': 519,
#  'websites': 520,
#  'different': 521,
#  'view': 522,
#  'necessity': 523,
#  'talk': 524,
#  'brake': 525,
#  'fluid': 526,
#  'exchange': 527,
#  'questionable': 528,
#  'checked': 529,
#  'agreeing': 530,
#  'fault': 531,
#  'charged': 532,
#  '159.95': 533,
#  'feeling': 534,
#  'repair': 535,
#  'expert': 536,
#  'affiliation': 537,
#  'related': 538,
#  'writing': 539,
#  'review': 540,
#  'informational': 541,
#  'purposes': 542,
#  'final': 543,
#  'comment': 544,
#  'buyer': 545,
#  'beware': 546,
#  'squid': 547,
#  'balls': 548,
#  'crispy': 549,
#  'exterior': 550,
#  'filling': 551,
#  'real': 552,
#  'pieces': 553,
#  'yummy': 554,
#  'flavoured': 555,
#  'salt': 556,
#  'fruit': 557,
#  'desserts': 558,
#  'worth': 559,
#  'imo': 560,
#  'mango': 561,
#  'diced': 562,
#  'jelly': 563,
#  'drink': 564,
#  'nothing': 565,
#  'special': 566,
#  'has': 567,
#  'nt': 568,
#  'herbal': 569,
#  'teas': 570,
#  'soups': 571,
#  'sure': 572,
#  'mooyah': 573,
#  'hit': 574,
#  'miss': 575,
#  'will': 576,
#  'start': 577,
#  'off': 578,
#  'saying': 579,
#  'especially': 580,
#  'fast': 581,
#  'polite': 582,
#  'ordering': 583,
#  'counter': 584,
#  'check': 585,
#  'eating': 586,
#  'location': 587,
#  '3': 588,
#  'times': 589,
#  'first': 590,
#  'pleased': 591,
#  'burger': 592,
#  'too': 593,
#  'greasy': 594,
#  'metal': 595,
#  'trays': 596,
#  'served': 597,
#  'dirty': 598,
#  'like': 599,
#  'washed': 600,
#  'between': 601,
#  'customers': 602,
#  'however': 603,
#  'recent': 604,
#  'trips': 605,
#  'noticed': 606,
#  'cleaner': 607,
#  'better': 608,
#  'well': 609,
#  'strawberry': 610,
#  'milkshake': 611,
#  '--': 612,
#  'yum': 613,
#  'regular': 614,
#  'old': 615,
#  'bbq': 616,
#  'skewers': 617,
#  'affordable': 618,
#  'eggrolls': 619,
#  'fat': 620,
#  'lumpia': 621,
#  'korean': 622,
#  'style': 623,
#  'ribs': 624,
#  'little': 625,
#  'farther': 626,
#  'than': 627,
#  'depot': 628,
#  'yelp': 629,
#  'coupon': 630,
#  'prices': 631,
#  'items': 632,
#  'purchased': 633,
#  'par': 634,
#  'lowest': 635,
#  'big': 636,
#  'box': 637,
#  'stores': 638,
#  'support': 639,
#  'local': 640,
#  'economy': 641,
#  'adequate': 642,
#  'selection': 643,
#  'close': 644,
#  'continue': 645,
#  'spend': 646,
#  'ever': 647,
#  'sandwiches': 648,
#  'sides': 649,
#  'chili': 650,
#  'jalapeno': 651,
#  'cornbread': 652,
#  'fries': 653,
#  'give': 654,
#  'disappointed': 655,
#  'beef': 656,
#  'sandwich': 657,
#  'hot': 658,
#  'peppers': 659,
#  'favorites': 660,
#  'bagels': 661,
#  'new': 662,
#  'jersey': 663,
#  'negative': 664,
#  'half': 665,
#  'parking': 666,
#  'gone': 667,
#  'chase': 668,
#  'bank': 669,
#  'being': 670,
#  'built': 671,
#  'already': 672,
#  'issue': 673,
#  'let': 674,
#  'say': 675,
#  'thai': 676,
#  'iv': 677,
#  'life': 678,
#  'egg': 679,
#  'homemade': 680,
#  'yellow': 681,
#  'curry': 682,
#  'shrimp': 683,
#  'fried': 684,
#  'rice': 685,
#  'finished': 686,
#  'meal': 687,
#  'coconut': 688,
#  'must': 689,
#  'urself': 690,
#  'favor': 691,
#  'baylee': 692,
#  'burrows': 693,
#  'quicken': 694,
#  'loans': 695,
#  'provided': 696,
#  'superior': 697,
#  'stayed': 698,
#  'top': 699,
#  'loan': 700,
#  'account': 701,
#  'finish': 702,
#  'weekly': 703,
#  'made': 704,
#  'questions': 705,
#  'answered': 706,
#  'feel': 707,
#  'bad': 708,
#  'asking': 709,
#  'maybe': 710,
#  'repetitive': 711,
#  'mortgaged': 712,
#  'each': 713,
#  'last': 714,
#  'fair': 715,
#  'costs': 716,
#  'rates': 717,
#  'returning': 718,
#  'client': 719,
#  'thank': 720,
#  'read': 721,
#  'reviews': 722,
#  'lousy': 723,
#  'family': 724,
#  'slow': 725,
#  'refill': 726,
#  'seemed': 727,
#  'forgot': 728,
#  'workers': 729,
#  'hanging': 730,
#  'hungry': 731,
#  'chinese': 732,
#  'immigrated': 733,
#  'generation': 734,
#  'plenty': 735,
#  'authentic': 736,
#  'thought': 737,
#  'northern': 738,
#  'does': 739,
#  'tasting': 740,
#  'anything': 741,
#  'silicon': 742,
#  'southern': 743,
#  'area': 744,
#  'longing': 745,
#  'used': 746,
#  'possibly': 747,
#  'satisfy': 748,
#  'taste': 749,
#  'guess': 750,
#  'catering': 751,
#  'below': 752,
#  'subpar': 753,
#  'freaking': 754,
#  'kyle': 755,
#  'us': 756,
#  'gave': 757,
#  'samples': 758,
#  'whatever': 759,
#  'wanted': 760,
#  'ended': 761,
#  'buying': 762,
#  'bottles': 763,
#  'hottie': 764,
#  'kitchen': 765,
#  'sink': 766,
#  'greens': 767,
#  'got': 768,
#  'green': 769,
#  'milk': 770,
#  'shake': 771,
#  'facebook': 772,
#  'free': 773,
#  'shot': 774,
#  'super': 775,
#  'intense': 776,
#  'opened': 777,
#  'sinuses': 778,
#  'cleared': 779,
#  'remember': 780,
#  'name': 781,
#  'ginger': 782,
#  'lemon': 783,
#  'cayenne': 784,
#  'pepper': 785,
#  'burned': 786,
#  'down': 787,
#  'lil': 788,
#  'starbucks': 789,
#  'busy': 790,
#  'lines': 791,
#  'mad': 792,
#  'wife': 793,
#  '3-day': 794,
#  'president': 795,
#  'weekend': 796,
#  '50th': 797,
#  'birthday': 798,
#  'reserved': 799,
#  'line': 800,
#  'hertz': 801,
#  'few': 802,
#  'earlier': 803,
#  'mercedes': 804,
#  'c': 805,
#  'class': 806,
#  'prestige': 807,
#  'collection': 808,
#  'selected': 809,
#  'reserve': 810,
#  'exact': 811,
#  'model': 812,
#  'signed': 813,
#  'gold': 814,
#  'membership': 815,
#  'ready': 816,
#  'able': 817,
#  'usually': 818,
#  'mccarran': 819,
#  'airport': 820,
#  'none': 821,
#  'these': 822,
#  'things': 823,
#  'happened': 824,
#  'reservation': 825,
#  '3:00': 826,
#  '2:48': 827,
#  'received': 828,
#  'email': 829,
#  'confirmation': 830,
#  'given': 831,
#  '#': 832,
#  'license': 833,
#  'plate': 834,
#  'identify': 835,
#  'color': 836,
#  'white': 837,
#  'explain': 838,
#  'situation': 839,
#  'walking': 840,
#  'tell': 841,
#  'somebody': 842,
#  'else': 843,
#  'office': 844,
#  'stand': 845,
#  'anyway': 846,
#  'worker': 847,
#  'tells': 848,
#  'available': 849,
#  'specifically': 850,
#  'choose': 851,
#  'supposedly': 852,
#  'waiting': 853,
#  'telling': 854,
#  'he': 855,
#  'cadillac': 856,
#  'cad': 857,
#  'ask': 858,
#  'held': 859,
#  'yah': 860,
#  'says': 861,
#  'why': 862,
#  'hold': 863,
#  '2': 864,
#  'cadillacs': 865,
#  '0': 866,
#  'agreed': 867,
#  'take': 868,
#  'wondering': 869,
#  'club': 870,
#  'promised': 871,
#  'around': 872,
#  'rental': 873,
#  'loco': 874,
#  'patrõn': 875,
#  'mexican': 876,
#  'expecting': 877,
#  'figured': 878,
#  'typical': 879,
#  'bar': 880,
#  'blown': 881,
#  'presentation': 882,
#  'fabulous': 883,
#  'prompt': 884,
#  'friends': 885,
#  'highly': 886,
#  'recommend': 887,
#  'expierence': 888,
#  'dip': 889,
#  'nails': 890,
#  'pedicures': 891,
#  'clean': 892,
#  'rush': 893,
#  'owner': 894,
#  'knows': 895,
#  'reasonable': 896,
#  'salons': 897,
#  'lift': 898,
#  'crack': 899,
#  'break': 900,
#  'colors': 901,
#  'suggestions': 902,
#  'styling': 903,
#  'spot': 904,
#  'dr.': 905,
#  'dameron': 906,
#  'his': 907,
#  'team': 908,
#  'dentist': 909,
#  'actually': 910,
#  'whole': 911,
#  'kind': 912,
#  'accommodating': 913,
#  'mention': 914,
#  'hygienists': 915,
#  'work': 916,
#  'teeth': 917,
#  'felt': 918,
#  'anyone': 919,
#  'needing': 920,
#  'concern': 921,
#  'products': 922,
#  'manager': 923,
#  'took': 924,
#  'ownership': 925,
#  'straightened': 926,
#  'starters': 927,
#  'shuttle': 928,
#  'hour': 929,
#  'appeared': 930,
#  'van': 931,
#  'bus': 932,
#  'use': 933,
#  'tons': 934,
#  'overpriced': 935,
#  'limos': 936,
#  'prepared': 937,
#  '12+per': 938,
#  'trip': 939,
#  'driver': 940,
#  'rude': 941,
#  'impatient': 942,
#  'yelled': 943,
#  'passengers': 944,
#  'majority': 945,
#  'hotel': 946,
#  'unfriendly': 947,
#  'ordeal': 948,
#  'room': 949,
#  'mini': 950,
#  'fridge': 951,
#  'empty': 952,
#  'cost': 953,
#  '25': 954,
#  'plus': 955,
#  '50': 956,
#  'careful': 957,
#  'touch': 958,
#  'something': 959,
#  'electronically': 960,
#  'monitored': 961,
#  'charge': 962,
#  'whether': 963,
#  'drank': 964,
#  'ate': 965,
#  'spoke': 966,
#  'fixed': 967,
#  'fix': 968,
#  'maid': 969,
#  'ridiculous': 970,
#  'informed': 971,
#  'contracted': 972,
#  'barely': 973,
#  'cleaned': 974,
#  'rooms': 975,
#  'replaced': 976,
#  'towels': 977,
#  'threw': 978,
#  'shampoos': 979,
#  'soaps': 980,
#  'onto': 981,
#  'everyday': 982,
#  'disturb': 983,
#  'sign': 984,
#  'night': 985,
#  'requested': 986,
#  'extra': 987,
#  'blankets': 988,
#  'hrs': 989,
#  '45': 990,
#  'minutes': 991,
#  'brought': 992,
#  'thin': 993,
#  'disgusting': 994,
#  'blanket': 995,
#  'lights': 996,
#  'burnt': 997,
#  'once': 998,
#  'dark': 999,
#  ...}

# %%
data_test = open(cfg["data"]["val_data"]).readlines()

# %%
print(data_test[5])
print(len(data_test))
# Out:
# {"label": 4.0, "text": ["i", "went", "out", "on", "a", "limb", "and", "it", "worked", "out", "great", "!", "i", "read", "the", "reviews", ",", "the", "location", "was", "ideal", "and", "when", "i", "walked", "in", "i", "was", "greeted", "with", "a", "smile", ",", "friendliness", "and", "willingness", "to", "answer", "my", "questions", "and", "the", "same", "thing", "happened", "when", "i", "picked", "up", "my", "ipad", ".", "the", "screen", "had", "been", "smashed", "from", "blunt", "force", ",", "not", "just", "a", "drop", ".", "i", "originally", "thought", ",", "this", "was", "it", "..", "new", "ipad", "needed", "based", "on", "how", "damaged", "it", "was", ".", "nope", "!", "great", "price", ",", "great", "service", ",", "and", "finished", "in", "a", "couple", "of", "hours", "and", "i", "was", "able", "to", "take", "advantage", "of", "the", "yelp", "deal", "!", "i", "won", "all", "they", "way", "around", ".", "nothing", "fancy", "here", ",", "just", "four", "walls", "and", "good", "people", ".", "i", "used", "to", "go", "up", "the", "road", "but", "found", "it", "to", "be", "about", "20", "-", "25", "%", "more", "expensive", "than", "phoenix", "iphone", "repairs", ".", "now", "i", "found", "the", "right", "place", "to", "take", "my", "iphone", "and", "ipad", "."]}
#
# 1000

# %% [markdown]
# #### Extracting the useful data for attention heatmap:

# %%
def package(data, dictionary):
    """Package data for training / evaluation."""
    data = list(map(lambda x: json.loads(x), data))
    text = list(map(lambda x: x["text"], data))
    dat = list(map(lambda x: list(map(lambda y: dictionary.word2idx[y], x['text'])), data))
    maxlen = 0
    for item in dat:
        maxlen = max(maxlen, len(item))
    targets = list(map(lambda x: x['label'], data))
    maxlen = min(maxlen, 500)
    for i in range(len(data)):
        if maxlen < len(dat[i]):
            dat[i] = dat[i][:maxlen]
        else:
            for j in range(maxlen - len(dat[i])):
                dat[i].append(dictionary.word2idx['<pad>'])
    dat = torch.LongTensor(dat)
    targets = torch.LongTensor(targets)
    return dat.t(), targets, text

# %%
model_bestval.eval()
@torch.no_grad()
def evaluate(cfg, model, data_eval):
    model.eval()  # turn on the eval() switch to disable dropout
    total_loss = 0
    total_correct = 0
    
    useful_data = []
    
    for batch, i in enumerate(range(0, len(data_eval), cfg["training"]["batch_size"])):
        data, targets, text = package(data_eval[i:min(len(data_eval), i+cfg["training"]["batch_size"])], dictionary)
        if cfg["cuda"]:
            data = data.cuda()
            targets = targets.cuda()
        hidden = model.init_hidden(data.size(1))
        output, attention, _ = model.forward(data, hidden)
        output_flat = output.view(data.size(1), -1)
        total_loss += criterion(output_flat, targets).data
        prediction = torch.max(output_flat, 1)[1]
        total_correct += torch.sum((prediction == targets).float())
        useful_data.append({'percentage_correct_pred': torch.sum((prediction == targets).float()).item()/cfg["training"]["batch_size"], 
                            'prediction':prediction.cpu().numpy(), 'label':targets.cpu().numpy(), 'attention':attention.cpu().numpy(), 'text':text})
    return total_loss.item() / (len(data_eval) // cfg["training"]["batch_size"]), total_correct.data.item() / len(data_eval), useful_data

# %%
criterion = nn.CrossEntropyLoss()
tot_loss, tot_correct, useful_data = evaluate(cfg, model_bestval, data_test)
print(tot_loss, tot_correct)
# Out:
# <ipython-input-17-871a9b89b17e>:18: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   targets = torch.LongTensor(targets)
# 0.8841343879699707 0.63

# %%
evaluate(cfg, model_bestacc, data_test)
tot_loss_2, tot_correct_2, useful_data_2 = evaluate(cfg, model_bestval, data_test)
print(tot_loss_2, tot_correct_2)
# Out:
# <ipython-input-17-871a9b89b17e>:18: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   targets = torch.LongTensor(targets)
# 0.8841343879699707 0.63

# %%
percentage = list(map(lambda x: x["percentage_correct_pred"], useful_data))

# %%
arg_max_pred = np.argmax(percentage)

# %%
useful_data[arg_max_pred]
# Out:
# {'percentage_correct_pred': 0.86,
#  'prediction': array([4, 4, 0, 4, 3, 4, 3, 4, 4, 4, 4, 4, 3, 4, 4, 4, 4, 4, 3, 4, 2, 0,
#         4, 4, 3, 4, 2, 4, 4, 4, 4, 1, 3, 3, 3, 3, 4, 4, 4, 0, 4, 4, 2, 4,
#         4, 3, 4, 4, 4, 2]),
#  'label': array([4, 0, 1, 4, 3, 4, 3, 4, 4, 4, 4, 4, 3, 4, 4, 3, 4, 4, 3, 4, 2, 0,
#         4, 4, 3, 4, 2, 4, 4, 4, 4, 2, 3, 3, 3, 3, 4, 4, 4, 0, 3, 2, 1, 4,
#         4, 3, 4, 4, 4, 2]),
#  'attention': array([[[6.9479982e-17, 3.7688202e-19, 2.4956808e-18, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.1756009e-10, 3.4919123e-11, 1.5651160e-10, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [8.4452915e-07, 7.5302398e-07, 4.4834234e-08, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [5.3873210e-18, 6.6278105e-17, 6.9929129e-18, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         [[5.4496979e-23, 1.4840667e-24, 2.5505597e-24, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.8656176e-16, 3.2612792e-19, 3.2086960e-20, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [7.0425165e-14, 2.4650541e-15, 2.6286839e-16, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.7522340e-24, 3.3445354e-21, 3.3099383e-20, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         [[7.8695925e-17, 2.2612814e-18, 8.6848981e-17, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.5426380e-23, 3.4478911e-21, 1.6568497e-20, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [9.8925734e-10, 2.6140927e-09, 1.3622234e-10, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.6449690e-07, 9.4680963e-10, 6.5627975e-11, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         ...,
#
#         [[7.2191480e-17, 3.1372791e-12, 1.0000000e+00, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [6.8874823e-17, 8.2922118e-18, 4.1562200e-23, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.0266489e-12, 2.7697115e-12, 3.2145783e-11, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [4.4385027e-16, 1.1791004e-16, 2.3181712e-13, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         [[2.1600027e-16, 5.5251471e-18, 1.2322599e-15, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [8.8369268e-12, 1.1934034e-07, 1.4186833e-06, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [2.4364141e-07, 4.3096370e-06, 1.2143711e-08, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [2.3413945e-06, 9.1044651e-11, 1.2275124e-12, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         [[9.6306538e-20, 5.9224961e-17, 6.0392485e-21, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [2.4303330e-15, 3.1838949e-22, 5.1195282e-21, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.1787088e-10, 1.5206451e-10, 5.8838501e-05, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [6.5432452e-08, 6.6552025e-01, 2.9426348e-01, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]]], dtype=float32),
#  'text': [['i',
#    'have',
#    'been',
#    'going',
#    'here',
#    'for',
#    'about',
#    'a',
#    'year',
#    '.',
#    'i',
#    'bring',
#    'my',
#    'daughter',
#    'as',
#    'well',
#    '.',
#    'they',
#    'do',
#    'an',
#    'excellent',
#    'job',
#    'every',
#    'time',
#    '.',
#    'i',
#    'usually',
#    'ask',
#    'for',
#    'lilly',
#    '.',
#    'she',
#    'is',
#    'awesome',
#    '.',
#    'i',
#    "'ve",
#    'never',
#    'seen',
#    'rudeness',
#    '.',
#    'true',
#    'they',
#    'do',
#    'get',
#    'very',
#    'busy',
#    '.',
#    'but',
#    'that',
#    'shows',
#    'how',
#    'good',
#    'they',
#    'are',
#    '.'],
#   ['i',
#    'have',
#    'to',
#    'say',
#    'that',
#    'i',
#    'was',
#    'just',
#    'appalled',
#    'by',
#    'the',
#    'attendants',
#    'in',
#    'the',
#    'show',
#    '.',
#    'this',
#    'was',
#    'a',
#    'very',
#    'fun',
#    'loud',
#    'amazing',
#    'show',
#    'and',
#    'everyone',
#    'was',
#    'dancing',
#    'and',
#    'clapping',
#    'and',
#    'singing',
#    'along',
#    'to',
#    'the',
#    'show',
#    '.',
#    'why',
#    'my',
#    'self',
#    ',',
#    'partner',
#    ',',
#    'and',
#    'best',
#    'friend',
#    'was',
#    'pin',
#    'pointed',
#    'out',
#    'as',
#    'being',
#    'to',
#    'loud',
#    'is',
#    'beyond',
#    'me',
#    '.',
#    'it',
#    "'s",
#    'sad',
#    'to',
#    'say',
#    'i',
#    'will',
#    'never',
#    'go',
#    'back',
#    'even',
#    'though',
#    'the',
#    'show',
#    'was',
#    'amazing',
#    '.',
#    'i',
#    'felt',
#    'discriminated',
#    'and',
#    'humiliated',
#    'that',
#    'they',
#    'can',
#    'dismiss',
#    'us',
#    'from',
#    'a',
#    'show',
#    'for',
#    'being',
#    'too',
#    'loud',
#    '.',
#    'i',
#    'am',
#    'a',
#    '45',
#    'year',
#    'old',
#    'woman',
#    'and',
#    'my',
#    'partner',
#    'is',
#    '55',
#    'and',
#    'you',
#    'are',
#    'really',
#    'going',
#    'to',
#    'kick',
#    'us',
#    'out',
#    'like',
#    'we',
#    'were',
#    'little',
#    'kids',
#    'that',
#    'would',
#    "n't",
#    'behave',
#    '..',
#    'i',
#    'am',
#    'not',
#    'al',
#    'all',
#    'a',
#    'negative',
#    'person',
#    'but',
#    'this',
#    'was',
#    'way',
#    'out',
#    'of',
#    'line',
#    'and',
#    'uncalled',
#    'for',
#    '.'],
#   ['new',
#    'in',
#    'town',
#    '&',
#    'this',
#    'place',
#    'was',
#    'recommended',
#    'to',
#    'my',
#    'husband',
#    'and',
#    'i',
#    'by',
#    'many',
#    'people',
#    '.',
#    'we',
#    'are',
#    'both',
#    'from',
#    'ca',
#    ',',
#    'so',
#    'we',
#    'know',
#    'good',
#    'mexican',
#    'food',
#    '.',
#    'we',
#    'have',
#    'been',
#    'living',
#    'in',
#    'italy',
#    'for',
#    'the',
#    'past',
#    'few',
#    'years',
#    ',',
#    'where',
#    'mexican',
#    'food',
#    'is',
#    'non',
#    '-',
#    'existent',
#    ',',
#    'so',
#    'we',
#    'were',
#    'looking',
#    'forward',
#    'to',
#    'eating',
#    'here',
#    '.',
#    'i',
#    'got',
#    'the',
#    '1',
#    'taco',
#    '&',
#    '1',
#    'enchilada',
#    'plate',
#    '&',
#    'my',
#    'husband',
#    'got',
#    'the',
#    '1',
#    'burrito',
#    '&',
#    '1',
#    'enchilada',
#    'plate',
#    '.',
#    'while',
#    'eating',
#    'the',
#    'beans',
#    'i',
#    'was',
#    'thinking',
#    'to',
#    'myself',
#    'how',
#    'salty',
#    'they',
#    'were',
#    ',',
#    '&',
#    'then',
#    'moved',
#    'on',
#    'to',
#    'the',
#    'taco',
#    'which',
#    'was',
#    'even',
#    'more',
#    'salty',
#    '.',
#    'it',
#    'tasted',
#    'like',
#    'i',
#    'was',
#    'eating',
#    'pure',
#    'salt',
#    '.',
#    'i',
#    'mentioned',
#    'it',
#    'to',
#    'my',
#    'husband',
#    ',',
#    '&',
#    'he',
#    'said',
#    'the',
#    'same',
#    'thing',
#    '.',
#    'needless',
#    'to',
#    'say',
#    ',',
#    'we',
#    'did',
#    'not',
#    'finish',
#    'our',
#    'food',
#    '.',
#    'will',
#    'not',
#    'be',
#    'eating',
#    'here',
#    'again',
#    '.'],
#   ['this',
#    'one',
#    'of',
#    'my',
#    'favorite',
#    'dining',
#    'experiences',
#    'ever',
#    '.',
#    'i',
#    'really',
#    'loved',
#    'the',
#    'adventure',
#    'and',
#    'mystery',
#    'of',
#    'the',
#    'whole',
#    'thing',
#    '.',
#    'it',
#    'was',
#    'a',
#    'fun',
#    'challenge',
#    'to',
#    'guess',
#    'food',
#    'and',
#    'an',
#    'even',
#    'more',
#    'interesting',
#    'one',
#    'to',
#    'try',
#    'and',
#    'use',
#    'utensils',
#    'in',
#    'the',
#    'dark',
#    '.',
#    'i',
#    "'d",
#    'highly',
#    'recommend',
#    'this',
#    'to',
#    'anybody',
#    'looking',
#    'for',
#    'an',
#    'out',
#    'of',
#    'the',
#    'box',
#    'dinner',
#    '.',
#    'you',
#    'really',
#    'ca',
#    "n't",
#    'see',
#    'anything',
#    'in',
#    'there',
#    ',',
#    'it',
#    "'s",
#    'pitch',
#    'black',
#    '.',
#    'although',
#    'sometimes',
#    'you',
#    'can',
#    'see',
#    'the',
#    'infrared',
#    'goggles',
#    'of',
#    'the',
#    'waiter',
#    'or',
#    'waitress',
#    'if',
#    'they',
#    "'re",
#    'looking',
#    'directly',
#    'at',
#    'you',
#    '.'],
#   ['my',
#    'hubby',
#    'and',
#    'i',
#    'stayed',
#    'at',
#    'the',
#    'venetian',
#    'during',
#    'the',
#    'week',
#    'last',
#    'week',
#    '.',
#    'the',
#    'price',
#    'was',
#    'great',
#    '(',
#    '169/night',
#    ')',
#    'with',
#    'a',
#    'package',
#    'that',
#    'included',
#    '$',
#    '40',
#    'off',
#    'the',
#    'phantom',
#    'of',
#    'the',
#    'opera',
#    'show',
#    'tickets',
#    '!',
#    'we',
#    'were',
#    'definitely',
#    'planning',
#    'on',
#    'seeing',
#    'it',
#    ',',
#    'so',
#    'it',
#    'was',
#    'perfect',
#    '!',
#    'there',
#    'were',
#    'other',
#    'discounts',
#    'in',
#    'the',
#    'package',
#    '(',
#    'to',
#    'an',
#    'asian',
#    'restaurant',
#    'and',
#    'a',
#    'mexican',
#    'one',
#    'at',
#    'palazzo',
#    ')',
#    'but',
#    'we',
#    'did',
#    "n't",
#    'use',
#    'those',
#    '.',
#    'the',
#    'venetian',
#    '...',
#    'omg',
#    ',',
#    'i',
#    'loved',
#    'that',
#    'place',
#    '!',
#    'the',
#    'perfume',
#    'scent',
#    'that',
#    'others',
#    'complain',
#    'about',
#    'in',
#    'their',
#    'reviews',
#    ',',
#    'actually',
#    'was',
#    "n't",
#    'bad',
#    '...',
#    'i',
#    'was',
#    'worried',
#    'about',
#    'it',
#    ',',
#    'being',
#    'highly',
#    'allergic',
#    'to',
#    'strong',
#    'smelling',
#    'perfumes',
#    ',',
#    'but',
#    'it',
#    'was',
#    'actually',
#    'really',
#    'nice',
#    '...',
#    'i',
#    'even',
#    'miss',
#    'it',
#    'now',
#    '...',
#    'i',
#    'did',
#    "n't",
#    'sneeze',
#    'at',
#    'all',
#    'from',
#    'it',
#    '.',
#    'we',
#    'arrived',
#    'early',
#    ',',
#    '2',
#    'pm',
#    ',',
#    'and',
#    'they',
#    'checked',
#    'is',
#    'in',
#    'no',
#    'problem',
#    '(',
#    '3',
#    'pm',
#    'is',
#    'checkin)',
#    '...',
#    'our',
#    'room',
#    'was',
#    'very',
#    '-',
#    'very',
#    'nice',
#    ',',
#    'my',
#    'hubby',
#    "'s",
#    'jaw',
#    'sort',
#    'of',
#    'dropped',
#    'when',
#    'he',
#    'first',
#    'saw',
#    'the',
#    'room',
#    '(',
#    'i',
#    'booked',
#    'the',
#    'whole',
#    'thing',
#    'so',
#    'i',
#    'already',
#    'saw',
#    'the',
#    'pictures',
#    ')',
#    '.',
#    'it',
#    'was',
#    'very',
#    'spacious',
#    ',',
#    'from',
#    'the',
#    'bathroom',
#    'to',
#    'the',
#    'bedroom',
#    '/',
#    'living',
#    'room',
#    '...',
#    '3',
#    'tvs',
#    'in',
#    'the',
#    'place',
#    '!',
#    'i',
#    'subtracted',
#    'a',
#    'star',
#    'though',
#    'b',
#    '/',
#    'c',
#    'our',
#    'tv',
#    'in',
#    'the',
#    'bathroom',
#    'did',
#    'not',
#    'work',
#    ':(',
#    'i',
#    'was',
#    'bummed',
#    'b',
#    '/',
#    'c',
#    'being',
#    'a',
#    'woman',
#    'i',
#    'spend',
#    'a',
#    'lotta',
#    'time',
#    'in',
#    'there',
#    ':)',
#    'the',
#    'pool',
#    'area',
#    'on',
#    'the',
#    '4th',
#    'floor',
#    'was',
#    'very',
#    'nice',
#    '(',
#    'there',
#    "'s",
#    'another',
#    'pool',
#    'with',
#    'more',
#    'shade',
#    'and',
#    'more',
#    'privacy',
#    'on',
#    'the',
#    '10th',
#    'floor',
#    'too)',
#    '...',
#    'i',
#    'did',
#    "n't",
#    'check',
#    'out',
#    'tao',
#    'beach',
#    ',',
#    'because',
#    'i',
#    'did',
#    'nt',
#    'even',
#    'realize',
#    'that',
#    'was',
#    'in',
#    'a',
#    'different',
#    'area',
#    'until',
#    'later',
#    '.',
#    'my',
#    'hubby',
#    'walked',
#    'by',
#    'it',
#    'and',
#    'said',
#    'it',
#    'was',
#    'nothing',
#    'major',
#    ',',
#    'so',
#    'i',
#    'believed',
#    'him',
#    '.',
#    'there',
#    'were',
#    'sufficient',
#    'chairs',
#    'at',
#    'the',
#    'pool',
#    ',',
#    'and',
#    'the',
#    'waitresses',
#    'came',
#    'by',
#    'occasionally',
#    'to',
#    'see',
#    'if',
#    'anyone',
#    'needed',
#    'drinks',
#    '.',
#    'they',
#    'could',
#    "'ve",
#    'made',
#    'more',
#    'money',
#    'personally',
#    'if',
#    'they',
#    'came',
#    'by',
#    'more',
#    'frequently',
#    '.',
#    'drinks',
#    'were',
#    'good',
#    ',',
#    'and',
#    'the',
#    'restaurant',
#    '(',
#    'riva',
#    'by',
#    'wolfgang',
#    'puck',
#    ')',
#    'has',
#    'really',
#    'good',
#    'lunch',
#    'menu',
#    '(',
#    'pizza',
#    'was',
#    'great',
#    ',',
#    'and',
#    'their',
#    'salads',
#    'too',
#    ')',
#    '.',
#    'overall',
#    ',',
#    'next',
#    'time',
#    'i',
#    "'m",
#    'in',
#    'vegas',
#    'i',
#    'will',
#    'definitely',
#    'stay',
#    'at',
#    'the',
#    'venetian',
#    '.'],
#   ['we',
#    'had',
#    'a',
#    'long',
#    'wait',
#    'for',
#    'our',
#    'food',
#    ',',
#    'but',
#    'it',
#    'was',
#    'worth',
#    'it',
#    '!',
#    'the',
#    'waiter',
#    'was',
#    'terrific',
#    ',',
#    'even',
#    'with',
#    'our',
#    'large',
#    'group',
#    '.',
#    'i',
#    'ordered',
#    'the',
#    'children',
#    "'s",
#    'size',
#    'spaghetti',
#    ',',
#    'which',
#    'he',
#    'probably',
#    'thought',
#    'was',
#    'for',
#    'my',
#    '3-year',
#    'old',
#    '-',
#    'granddaughter',
#    ',',
#    'and',
#    'it',
#    'was',
#    'the',
#    'perfect',
#    'size',
#    'for',
#    'me',
#    '!',
#    'if',
#    'you',
#    'do',
#    "n't",
#    'want',
#    'to',
#    'wait',
#    'for',
#    'hours',
#    ',',
#    'consider',
#    'going',
#    'early',
#    'in',
#    'the',
#    'evening',
#    '!'],
#   ['there',
#    "'s",
#    'not',
#    'much',
#    'choice',
#    'in',
#    'pickering',
#    'when',
#    'you',
#    'want',
#    'something',
#    'with',
#    'good',
#    'food',
#    'and',
#    'a',
#    'great',
#    'view',
#    '.',
#    'i',
#    'had',
#    'never',
#    'even',
#    'heard',
#    'of',
#    'the',
#    'port',
#    ';',
#    'my',
#    'wife',
#    'and',
#    'i',
#    'were',
#    'given',
#    'a',
#    'gift',
#    'card',
#    'for',
#    'this',
#    'restaurant',
#    'with',
#    'a',
#    'car',
#    'purchase',
#    '.',
#    'as',
#    'it',
#    "'s",
#    'just',
#    'around',
#    'the',
#    'corner',
#    'from',
#    'us',
#    ',',
#    'we',
#    'decided',
#    'to',
#    'walk',
#    'there',
#    'for',
#    'dinner',
#    'and',
#    'have',
#    'a',
#    'few',
#    'drinks',
#    ',',
#    'too',
#    '.',
#    'once',
#    'through',
#    'the',
#    'front',
#    'door',
#    ',',
#    'it',
#    'was',
#    'almost',
#    'as',
#    'if',
#    'we',
#    "'d",
#    'walked',
#    'into',
#    'any',
#    'of',
#    'a',
#    'number',
#    'of',
#    'downtown',
#    'restaurants',
#    '.',
#    'the',
#    'decor',
#    'was',
#    'open',
#    'and',
#    'modern',
#    ',',
#    'and',
#    'the',
#    'music',
#    'was',
#    'unobtrusive',
#    '"',
#    'hip',
#    '"',
#    'dining',
#    'music',
#    '.',
#    '(',
#    'somewhat',
#    'electronic',
#    ',',
#    'with',
#    'nothing',
#    'at',
#    'all',
#    'to',
#    'catch',
#    'your',
#    'attention',
#    'either',
#    'positively',
#    'or',
#    'negatively',
#    '.',
#    'there',
#    'must',
#    'be',
#    'a',
#    'small',
#    'fortune',
#    'in',
#    'making',
#    'this',
#    'modern',
#    'take',
#    'on',
#    'musak',
#    '.',
#    ')',
#    'we',
#    'were',
#    'offered',
#    'a',
#    'seat',
#    'in',
#    'the',
#    'lounge',
#    'as',
#    'the',
#    'dining',
#    'room',
#    'was',
#    'full',
#    '.',
#    'we',
#    'sat',
#    'by',
#    'the',
#    'fireplace',
#    'which',
#    'was',
#    'nice',
#    '.',
#    'through',
#    'the',
#    'window',
#    'we',
#    'saw',
#    'a',
#    'great',
#    'patio',
#    'on',
#    'frenchman',
#    "'s",
#    'bay',
#    'which',
#    'will',
#    'be',
#    'a',
#    'definite',
#    'hang',
#    '-',
#    'out',
#    'for',
#    'us',
#    'this',
#    'summer',
#    '!',
#    'we',
#    'started',
#    'with',
#    'drinks',
#    'which',
#    'were',
#    'very',
#    'reasonably',
#    'priced',
#    '.',
#    '(',
#    'five',
#    'bucks',
#    'for',
#    'a',
#    'bottle',
#    'of',
#    'steamwhistle',
#    '?',
#    '!',
#    'maybe',
#    'moving',
#    'to',
#    'the',
#    'suburbs',
#    'does',
#    'have',
#    'it',
#    "'s",
#    'benefits',
#    '!',
#    '!',
#    '!',
#    ')',
#    'we',
#    'also',
#    'got',
#    'a',
#    'small',
#    'dish',
#    'of',
#    'spiced',
#    'olives',
#    'to',
#    'nibble',
#    'at',
#    'while',
#    'we',
#    'waited',
#    '.',
#    'the',
#    'staff',
#    'was',
#    'friendly',
#    ',',
#    'competent',
#    'and',
#    'efficient',
#    ',',
#    'and',
#    'they',
#    'all',
#    'seemed',
#    'to',
#    'be',
#    'working',
#    'hard',
#    'and',
#    'cheerfully',
#    '.',
#    'i',
#    'ordered',
#    'the',
#    'free',
#    'range',
#    'chicken',
#    'and',
#    'my',
#    'wife',
#    'ordered',
#    'the',
#    'salmon',
#    '.',
#    'chicken',
#    ':',
#    'a',
#    'breast',
#    'of',
#    'free',
#    'range',
#    'chicken',
#    'roasted',
#    'with',
#    'comfort',
#    'cream',
#    'cheese',
#    'and',
#    'topped',
#    'with',
#    'onion',
#    'marmalade',
#    ',',
#    'served',
#    'with',
#    'a',
#    'port',
#    'poached',
#    'pear',
#    'and',
#    'finished',
#    'with',
#    'wine',
#    'syrup',
#    'and',
#    'sage',
#    'aioli',
#    '.',
#    'this',
#    'dish',
#    'was',
#    'absolutely',
#    'fantastic',
#    '.',
#    'the',
#    'harmony',
#    'of',
#    'these',
#    'five',
#    'ingredients',
#    'was',
#    'just',
#    'wonderful',
#    '.',
#    'every',
#    'bite',
#    'was',
#    'something',
#    'special',
#    'and',
#    'i',
#    'thoroughly',
#    'enjoyed',
#    'this',
#    'dish',
#    '.',
#    'the',
#    'sweet',
#    'pear',
#    'and',
#    'the',
#    'savory',
#    'sage',
#    'aioli',
#    'were',
#    'a',
#    'beautiful',
#    'combination',
#    ',',
#    'the',
#    'chicken',
#    'was',
#    'moist',
#    'and',
#    'cooked',
#    'perfectly',
#    ',',
#    'and',
#    'the',
#    'wine',
#    'syrup',
#    'added',
#    'a',
#    'very',
#    'pleasing',
#    'bright',
#    'note',
#    '.',
#    'i',
#    'would',
#    'order',
#    'it',
#    'again',
#    'in',
#    'a',
#    'heartbeat',
#    '.',
#    'the',
#    'applewood',
#    'cheddar',
#    'mashed',
#    'potatoes',
#    'were',
#    'also',
#    'excellent',
#    ',',
#    'with',
#    'the',
#    'cheddar',
#    'adding',
#    'a',
#    'nicely',
#    'muted',
#    'sharpness',
#    'to',
#    'the',
#    'potato',
#    '.',
#    'the',
#    'other',
#    'seasonal',
#    'vegetables',
#    'were',
#    'asparagus',
#    ',',
#    'not',
#    'overcooked',
#    ',',
#    'and',
#    'possibly',
#    'the',
#    'best',
#    'mashed',
#    'turnip',
#    'i',
#    "'ve",
#    'ever',
#    'had',
#    '.',
#    'salmon',
#    ':',
#    'this',
#    'is',
#    'a',
#    'wasabi',
#    '-',
#    'pea',
#    'encrusted',
#    'salmon',
#    'on',
#    'a',
#    'bed',
#    'of',
#    'basmati',
#    'rice',
#    'and',
#    'vegetables',
#    '.',
#    'i',
#    'did',
#    "n't",
#    'try',
#    'the',
#    'vegetables',
#    'but',
#    'they',
#    'included',
#    'soy',
#    'glazed',
#    'water',
#    'chestnut',
#    ',',
#    'baby',
#    'corn',
#    '(',
#    'which',
#    'always',
#    'fails',
#    'to',
#    'impress',
#    'me',
#    'as',
#    'they',
#    'often',
#    'look',
#    'like',
#    'something',
#    'taken',
#    'straight',
#    'from',
#    'a',
#    'can',
#    'and',
#    'put',
#    'on',
#    'a',
#    'cheap',
#    'salad',
#    'bar',
#    ')',
#    ',',
#    'bamboo',
#    'shoots',
#    ',',
#    'hearts',
#    'of',
#    'palm',
#    'and',
#    'bok',
#    'choi',
#    '.',
#    'i',
#    'tasted',
#    'the',
#    'salmon',
#    'and',
#    'the',
#    'wasabi',
#    'that',
#    'encrusted',
#    'the',
#    'top',
#    'of',
#    'the',
#    'fish',
#    'was',
#    'a',
#    'very',
#    'nice',
#    'touch',
#    '.',
#    'she',
#    'said',
#    'she',
#    'enjoyed',
#    'the',
#    'dish',
#    'a',
#    'lot',
#    'but',
#    'was',
#    'a',
#    'little',
#    'underwhelmed',
#    'with',
#    'the',
#    'vegetables',
#    '.',
#    'they',
#    'were',
#    'good',
#    ',',
#    'but',
#    'nothing',
#    'too',
#    'special',
#    '.',
#    'after',
#    'another',
#    'round',
#    'of',
#    'steamwhistles',
#    ',',
#    'we',
#    'decided',
#    'to',
#    'order',
#    'a',
#    'nightcap',
#    'and',
#    'head',
#    'home',
#    '.',
#    'i',
#    'had',
#    'a',
#    'maker',
#    "'s",
#    'mark',
#    ',',
#    'she',
#    'had',
#    'a',
#    'bluberri',
#    'stoli',
#    '.',
#    'and',
#    'here',
#    "'s",
#    'the',
#    'kicker',
#    ':',
#    'a',
#    'small',
#    'appetizer',
#    ',',
#    'four',
#    'decent',
#    'beers',
#    ',',
#    'two',
#    'great',
#    'meals',
#    ',',
#    'and',
#    'two',
#    'final',
#    'drinks',
#    '......',
#    'under',
#    'a',
#    'hundred',
#    'bucks',
#    'including',
#    'tax',
#    '(',
#    'before',
#    'tip',
#    ')',
#    '.',
#    'at',
#    'that',
#    'price',
#    ',',
#    'for',
#    'that',
#    'quality',
#    ',',
#    'tipping',
#    'is',
#    'a',
#    'pleasure',
#    '!',
#    'we',
#    'will',
#    'definitely',
#    'be',
#    'returning',
#    ',',
#    'often',
#    '.'],
#   ['we',
#    'love',
#    'the',
#    'thumb',
#    ',',
#    'come',
#    'to',
#    'get',
#    'our',
#    'car',
#    'washed',
#    'and',
#    'have',
#    'breakfast',
#    'or',
#    'lunch',
#    'or',
#    'dinner',
#    ',',
#    'just',
#    'depending',
#    'on',
#    'the',
#    'time',
#    'of',
#    'the',
#    'day',
#    '.',
#    'the',
#    'brisket',
#    'sandwich',
#    'is',
#    'the',
#    'best',
#    'there',
#    'is',
#    '(',
#    'or',
#    'anything',
#    'with',
#    'brisket',
#    '!',
#    '!',
#    ')',
#    '.',
#    'the',
#    'fries',
#    'are',
#    'just',
#    'the',
#    'right',
#    'amount',
#    'of',
#    'crisp',
#    '.',
#    'staff',
#    'is',
#    'great',
#    ',',
#    'especially',
#    'the',
#    'car',
#    'wash',
#    'staff',
#    'who',
#    'do',
#    'an',
#    'awesome',
#    'and',
#    'consistent',
#    'job',
#    '.',
#    'looking',
#    'forward',
#    'to',
#    'enjoying',
#    'the',
#    'newly',
#    'remodeled',
#    'patio',
#    'this',
#    'fall',
#    '!'],
#   ['i',
#    'ordered',
#    'the',
#    'akropolis',
#    'pizza',
#    'and',
#    'pork',
#    'gyro',
#    '.',
#    'the',
#    'first',
#    'thing',
#    'i',
#    'noticed',
#    'when',
#    'the',
#    'pizza',
#    'came',
#    'out',
#    'was',
#    'how',
#    'vibrant',
#    'the',
#    'toppings',
#    'were',
#    '!',
#    'you',
#    'can',
#    'tell',
#    'the',
#    'veggies',
#    'are',
#    'fresh',
#    'just',
#    'by',
#    'looking',
#    'at',
#    'them',
#    '.',
#    'the',
#    'gyro',
#    'was',
#    'one',
#    'of',
#    'the',
#    'best',
#    'i',
#    "'ve",
#    'had',
#    'and',
#    'the',
#    'fries',
#    'were',
#    'awesome',
#    '.',
#    'great',
#    'service',
#    '!',
#    'they',
#    'really',
#    'care',
#    'about',
#    'giving',
#    'you',
#    'a',
#    'good',
#    'experience',
#    '.',
#    'i',
#    'will',
#    'definitely',
#    'be',
#    'back',
#    '!'],
#   ['you',
#    'have',
#    'to',
#    'go',
#    'to',
#    'this',
#    'place',
#    'to',
#    'try',
#    'chinese',
#    '-',
#    'fusion',
#    'cuisine',
#    '.',
#    'we',
#    'have',
#    'a',
#    'very',
#    'sweet',
#    'server',
#    'who',
#    'helped',
#    'us',
#    'in',
#    'selecting',
#    'a',
#    'few',
#    'items',
#    'as',
#    'per',
#    'our',
#    'preference',
#    'and',
#    'spice',
#    'tolerance',
#    '.',
#    'all',
#    'the',
#    'servers',
#    'are',
#    'very',
#    'sweet',
#    'and',
#    'friendly',
#    '.',
#    'try',
#    'the',
#    'sweet',
#    'corn',
#    'soup',
#    ',',
#    'chicken',
#    'manchurian',
#    'if',
#    'is',
#    'very',
#    'soft',
#    'and',
#    'not',
#    'too',
#    'spicy',
#    '.',
#    'american',
#    'chopsuey',
#    'is',
#    'also',
#    'one',
#    'of',
#    'our',
#    'favorites',
#    '.',
#    'thank',
#    'you',
#    'inchin',
#    'bamboo',
#    'garden',
#    'for',
#    'great',
#    'service',
#    'and',
#    'food',
#    ')'],
#   ['what',
#    'a',
#    'great',
#    'place',
#    '!',
#    'love',
#    'the',
#    'food',
#    'and',
#    'the',
#    'atmosphere',
#    '!',
#    'i',
#    'was',
#    'in',
#    'last',
#    'friday',
#    'and',
#    'although',
#    'it',
#    'was',
#    'packed',
#    'due',
#    'to',
#    'phoenix',
#    'comicon',
#    ',',
#    'a',
#    'dbacks',
#    'game',
#    ',',
#    'the',
#    'phoeinix',
#    'symphony',
#    'and',
#    'first',
#    'friday',
#    '...',
#    'we',
#    'got',
#    'a',
#    'table',
#    'in',
#    'the',
#    'bar',
#    ',',
#    'had',
#    'attentive',
#    'service',
#    'and',
#    'made',
#    'it',
#    'out',
#    'just',
#    'in',
#    'time',
#    'to',
#    'make',
#    'it',
#    'to',
#    'the',
#    'phoenix',
#    'symphony',
#    'for',
#    'our',
#    'show',
#    '!',
#    'my',
#    'boyfriend',
#    'and',
#    'i',
#    'went',
#    'in',
#    'yesterday',
#    'to',
#    'enjoy',
#    'some',
#    'drinks',
#    'and',
#    'appetizers',
#    'for',
#    'the',
#    'afternoon',
#    'and',
#    'had',
#    'a',
#    'wonderful',
#    'time',
#    'again',
#    '!',
#    'lauren',
#    'was',
#    'our',
#    'server',
#    'and',
#    'she',
#    'was',
#    'fabulous',
#    '!',
#    'again',
#    'attentive',
#    'and',
#    'made',
#    'sure',
#    'we',
#    'had',
#    'everything',
#    'we',
#    'needed',
#    '!',
#    'i',
#    'will',
#    'definitely',
#    'be',
#    'back',
#    '!'],
#   ['i',
#    'am',
#    'not',
#    'surprised',
#    'to',
#    'see',
#    'all',
#    'the',
#    '5',
#    'star',
#    'reviews',
#    '.',
#    'victor',
#    'guerrero',
#    'has',
#    'got',
#    'window',
#    'tinting',
#    'down',
#    'pat',
#    '.',
#    'very',
#    'fair',
#    'prices',
#    'considering',
#    'the',
#    'quality',
#    'of',
#    'tint',
#    'he',
#    'uses',
#    '.',
#    'he',
#    "'s",
#    'done',
#    '4',
#    'cars',
#    'of',
#    'mine',
#    'in',
#    'the',
#    'past',
#    'and',
#    'i',
#    'never',
#    'had',
#    'a',
#    'single',
#    'issue',
#    'with',
#    'any',
#    'of',
#    'them',
#    '.',
#    'definately',
#    'recommend',
#    '!'],
#   ['this',
#    'was',
#    'one',
#    'of',
#    'those',
#    'hipster',
#    'trendy',
#    'places',
#    'that',
#    'make',
#    'pho',
#    'cool',
#    '.',
#    'or',
#    'shall',
#    'i',
#    'say',
#    'hot',
#    '?',
#    ';)',
#    'ok',
#    'bad',
#    'joke',
#    '.',
#    'but',
#    'i',
#    'ordered',
#    '"',
#    'the',
#    'american',
#    '"',
#    ',',
#    'super',
#    'good-',
#    'it',
#    "'s",
#    'basically',
#    'beef',
#    'pho',
#    '.',
#    'it',
#    'was',
#    '$',
#    '10',
#    'though',
#    ',',
#    'which',
#    'is',
#    'fine',
#    'but',
#    'i',
#    "'m",
#    'used',
#    'to',
#    'paying',
#    'cheaper',
#    'than',
#    '6',
#    'dollars',
#    'for',
#    'pho',
#    '.',
#    'also',
#    ',',
#    'i',
#    'feel',
#    'like',
#    'pho',
#    'is',
#    'known',
#    'for',
#    'how',
#    'cheap',
#    'it',
#    'is',
#    'and',
#    'how',
#    'big',
#    'portions',
#    'you',
#    'get',
#    '.',
#    'the',
#    'food',
#    'was',
#    'really',
#    'tasty',
#    '.',
#    'there',
#    'is',
#    'a',
#    'little',
#    'self',
#    'serve',
#    'pho',
#    'bar',
#    ',',
#    'where',
#    'you',
#    'get',
#    'your',
#    'sides',
#    'like',
#    'sauce',
#    ',',
#    'limes',
#    ',',
#    'bamboo',
#    ',',
#    'greens',
#    ',',
#    'etc',
#    '.',
#    'i',
#    'like',
#    'how',
#    'the',
#    'restaurant',
#    'has',
#    'their',
#    'own',
#    'variety',
#    'of',
#    'sauces',
#    'to',
#    'add',
#    'to',
#    'your',
#    'pho',
#    '.',
#    'i',
#    'did',
#    'also',
#    'notice',
#    'that',
#    'the',
#    'soup',
#    'did',
#    "n't",
#    'come',
#    'with',
#    'that',
#    'much',
#    'noodles',
#    '.',
#    'there',
#    'was',
#    'a',
#    'lot',
#    'of',
#    'beef',
#    'though',
#    '!',
#    'which',
#    'is',
#    'a',
#    'plus',
#    '.',
#    'the',
#    'proportions',
#    'did',
#    "n't",
#    'really',
#    'even',
#    'out',
#    '.',
#    '4',
#    'stars',
#    'for',
#    'the',
#    'food',
#    'and',
#    'friendly',
#    'customer',
#    'service',
#    '.',
#    'minus',
#    'one',
#    'star',
#    'because',
#    'of',
#    'the',
#    'price',
#    '.',
#    'i',
#    'think',
#    'all',
#    'genuine',
#    'pho',
#    'lovers',
#    'can',
#    'agree',
#    'with',
#    'me',
#    'though',
#    ',',
#    'pho',
#    'is',
#    'usually',
#    'cheap',
#    '!'],
#   ['every',
#    'time',
#    'i',
#    'go',
#    'here',
#    'and',
#    'order',
#    'milk',
#    'tea',
#    'it',
#    'just',
#    'gets',
#    'better',
#    'and',
#    'better',
#    ',',
#    'staff',
#    'is',
#    'very',
#    'nice',
#    'too',
#    '!',
#    'i',
#    'have',
#    'my',
#    'regular',
#    'server',
#    ',',
#    'name',
#    'is',
#    'puck',
#    'i',
#    'believe',
#    ',',
#    'very',
#    'accommodating',
#    '.'],
#   ['wow',
#    '!',
#    'this',
#    'was',
#    'the',
#    'best',
#    'pedicure',
#    'that',
#    'i',
#    'have',
#    'had',
#    'in',
#    'a',
#    'long',
#    'time',
#    '.',
#    'i',
#    'had',
#    'one',
#    'not',
#    'too',
#    'long',
#    'ago',
#    'at',
#    'oasis',
#    'day',
#    'spa',
#    'for',
#    '$',
#    '60',
#    'and',
#    'it',
#    'did',
#    "n't",
#    'even',
#    'compare',
#    '.',
#    'they',
#    'recently',
#    'got',
#    'new',
#    'massage',
#    'pedicure',
#    'chairs',
#    'that',
#    'are',
#    'amazing',
#    '!',
#    'for',
#    'only',
#    '$',
#    '30.00',
#    'it',
#    'was',
#    'really',
#    'great',
#    'service',
#    '.',
#    'they',
#    'really',
#    'take',
#    'their',
#    'time',
#    'and',
#    'give',
#    'you',
#    'an',
#    'amazing',
#    'foot',
#    'and',
#    'leg',
#    'massage',
#    'and',
#    'the',
#    'people',
#    'are',
#    'extremely',
#    'friendly',
#    '.',
#    'they',
#    'even',
#    'offered',
#    'us',
#    'each',
#    'a',
#    'bottle',
#    'of',
#    'water',
#    'when',
#    'we',
#    'walked',
#    'in',
#    '.',
#    'i',
#    'will',
#    'definitely',
#    'be',
#    'back',
#    'and',
#    'i',
#    'sent',
#    'my',
#    'mom',
#    'there',
#    'and',
#    'she',
#    'loved',
#    'it',
#    'too',
#    '!',
#    'no',
#    'more',
#    'groupon',
#    'pedicures',
#    'for',
#    'me',
#    '!'],
#   ['love',
#    'the',
#    'chile',
#    'relleno',
#    ',',
#    'get',
#    'it',
#    'with',
#    'the',
#    'ranchero',
#    'sauce',
#    'on',
#    'the',
#    'side',
#    'so',
#    'you',
#    'can',
#    'enjoy',
#    'the',
#    'crispy',
#    'relleno',
#    'and',
#    'still',
#    'get',
#    'the',
#    'tasty',
#    'ranchero',
#    'sauce',
#    '.',
#    'the',
#    'nachos',
#    'serving',
#    'was',
#    'so',
#    'huge',
#    ',',
#    'my',
#    'kids',
#    'shared',
#    'it',
#    'and',
#    'still',
#    'brought',
#    'some',
#    'home',
#    '.',
#    'super',
#    'friendly',
#    'service',
#    '.'],
#   ['i',
#    'love',
#    'what',
#    'bonnie',
#    'brooks',
#    'the',
#    'former',
#    'ceo',
#    'has',
#    'done',
#    'to',
#    'revive',
#    'the',
#    'hudson',
#    'bay',
#    'stores',
#    '.',
#    'i',
#    'had',
#    'the',
#    'pleasure',
#    'of',
#    'shopping',
#    'at',
#    'lane',
#    'crawford',
#    'in',
#    'hong',
#    'kong',
#    ',',
#    'another',
#    'place',
#    'bonnie',
#    'has',
#    'left',
#    'her',
#    'fingerprint',
#    '.',
#    'the',
#    'hudson',
#    'bay',
#    'was',
#    'my',
#    'go',
#    'to',
#    'store',
#    '15',
#    '+',
#    'years',
#    'ago',
#    'and',
#    'i',
#    'stopped',
#    'shopping',
#    'their',
#    'about',
#    '10',
#    'years',
#    'ago',
#    'as',
#    'they',
#    'began',
#    'to',
#    'diversify',
#    'too',
#    'much',
#    'and',
#    'became',
#    'and',
#    'expert',
#    'at',
#    'nothing',
#    'including',
#    'fashion',
#    '.',
#    'bonnie',
#    ',',
#    'the',
#    'former',
#    'ceo',
#    'of',
#    'hudson',
#    'bay',
#    'has',
#    'started',
#    'a',
#    'transition',
#    'back',
#    'to',
#    'its',
#    'roots',
#    'and',
#    'bringing',
#    'in',
#    'a',
#    'lot',
#    'of',
#    'high',
#    'end',
#    'exclusive',
#    'lines',
#    'and',
#    'departments',
#    'including',
#    'reviving',
#    'the',
#    'room',
#    'at',
#    'its',
#    'flagship',
#    'location',
#    'and',
#    'as',
#    'a',
#    'result',
#    ',',
#    'gone',
#    'is',
#    'the',
#    'tv',
#    'department',
#    'and',
#    'other',
#    'high',
#    'maintenance',
#    'low',
#    'profit',
#    'lines',
#    '.',
#    'i',
#    'do',
#    'find',
#    'myself',
#    'suddenly',
#    'dropping',
#    'in',
#    'to',
#    'see',
#    'what',
#    'is',
#    'new',
#    'and',
#    'always',
#    'seem',
#    'to',
#    'walk',
#    'out',
#    'with',
#    'a',
#    'purchase',
#    '.',
#    'good',
#    'show',
#    'bonnie',
#    ',',
#    'nice',
#    'to',
#    'have',
#    'you',
#    'back',
#    'in',
#    'toronto',
#    '.',
#    'i',
#    'hope',
#    'the',
#    'new',
#    'ceo',
#    'has',
#    'the',
#    'same',
#    'clear',
#    'vision',
#    'bonnie',
#    'had',
#    'while',
#    'at',
#    'the',
#    'wheel',
#    '.'],
#   ['we',
#    'have',
#    'only',
#    'been',
#    'through',
#    'the',
#    'drive',
#    'thru',
#    'so',
#    'i',
#    'have',
#    'no',
#    'idea',
#    'what',
#    'it',
#    'is',
#    'like',
#    'inside',
#    '...',
#    'but',
#    'their',
#    'food',
#    'is',
#    'bomb',
#    '.',
#    'such',
#    'a',
#    'great',
#    'bean',
#    'burro',
#    '!',
#    'they',
#    'are',
#    'also',
#    'always',
#    'very',
#    'nice',
#    ':)'],
#   ['has',
#    'a',
#    'california',
#    'beachfront',
#    'feel',
#    'to',
#    'the',
#    'restaurant',
#    '.',
#    'from',
#    'swimming',
#    'trunks',
#    'and',
#    'bikini',
#    "'s",
#    'hang',
#    'from',
#    'ceiling',
#    ',',
#    'to',
#    'the',
#    'surfboards',
#    'hanging',
#    'on',
#    'the',
#    'walls',
#    '.',
#    'very',
#    'friendly',
#    'staff',
#    'and',
#    'the',
#    'food',
#    'is',
#    'good',
#    ',',
#    'a',
#    'bit',
#    'pricey',
#    'but',
#    'good',
#    '.'],
#   ['while',
#    'visiting',
#    'during',
#    'a',
#    'conference',
#    'we',
#    'first',
#    'ate',
#    'here',
#    'for',
#    'lunch',
#    '.',
#    'service',
#    'was',
#    'outstanding',
#    'and',
#    'the',
#    'food',
#    'was',
#    'nothing',
#    'short',
#    'of',
#    'delicious',
#    '.',
#    'i',
#    'had',
#    'the',
#    'swine',
#    'burger',
#    '2.0',
#    'that',
#    'hit',
#    'the',
#    'spot',
#    '!',
#    'on',
#    'a',
#    'different',
#    'night',
#    'i',
#    'had',
#    'the',
#    'pork',
#    'ribs',
#    'that',
#    'had',
#    'a',
#    'phenomenal',
#    'flavor',
#    'with',
#    'a',
#    'bit',
#    'of',
#    'spice',
#    '.',
#    'everything',
#    'was',
#    'great',
#    'and',
#    'again',
#    'the',
#    'service',
#    'was',
#    'outstanding',
#    '...',
#    'highly',
#    'recommend',
#    '.'],
#   ['the',
#    'cost',
#    'model',
#    'is',
#    'very',
#    'good',
#    '.',
#    'middling',
#    'quality',
#    'sushi',
#    'but',
#    'no',
#    'plate',
#    'is',
#    'priced',
#    'over',
#    '$',
#    '2',
#    '.',
#    'so',
#    'honestly',
#    ',',
#    'for',
#    'my',
#    'budget',
#    ',',
#    'i',
#    "'d",
#    'eat',
#    'here',
#    'more',
#    'often',
#    'b',
#    '/',
#    'c',
#    'it',
#    'is',
#    'good',
#    'for',
#    'a',
#    'quick',
#    'cheap',
#    'sushi',
#    'fix',
#    'than',
#    'if',
#    'it',
#    'was',
#    'pricey',
#    'for',
#    'good',
#    'quality',
#    'sushi',
#    '.',
#    'the',
#    'only',
#    'standouts',
#    '--',
#    'eel',
#    'and',
#    'this',
#    'other',
#    'plate',
#    'of',
#    'krab',
#    'w/',
#    'tuna',
#    'slice',
#    'wrapped',
#    'around',
#    'it',
#    'w/',
#    'avacado',
#    'on',
#    'it',
#    '.',
#    'i',
#    'would',
#    "n't",
#    'take',
#    'a',
#    'die',
#    'hard',
#    'sushi',
#    'fan',
#    'here',
#    ',',
#    'but',
#    'i',
#    'would',
#    'take',
#    'someone',
#    'who',
#    'does',
#    "n't",
#    'eat',
#    'sushi',
#    'much',
#    'so',
#    'would',
#    "n't",
#    'care',
#    'anyhow',
#    'and',
#    'would',
#    'enjoy',
#    'the',
#    'conveyer',
#    'belt',
#    'concept',
#    '.'],
#   ['they',
#    'odds',
#    'of',
#    'winning',
#    'are',
#    'bad',
#    '!',
#    'you',
#    'are',
#    'more',
#    'likely',
#    'to',
#    'get',
#    'slap',
#    'with',
#    'a',
#    'frog',
#    'than',
#    'wining',
#    'something',
#    'above',
#    '50',
#    'cents',
#    '!',
#    'my',
#    'friends',
#    'and',
#    'i',
#    'each',
#    'spend',
#    'money',
#    'and',
#    'we',
#    'did',
#    "n't",
#    'even',
#    'got',
#    'teased',
#    '!'],
#   ['i',
#    'went',
#    'for',
#    'color',
#    'and',
#    'jennifer',
#    'was',
#    'amazing',
#    '.',
#    'she',
#    'was',
#    'super',
#    'sweet',
#    'and',
#    'made',
#    'sure',
#    'my',
#    'hair',
#    'was',
#    'exactly',
#    'how',
#    'i',
#    'wanted',
#    'it',
#    '...',
#    'even',
#    'though',
#    'i',
#    "'m",
#    'picky',
#    'and',
#    'she',
#    'had',
#    'to',
#    'redo',
#    'a',
#    'section',
#    '.',
#    'i',
#    'will',
#    'for',
#    'sure',
#    'be',
#    'returning',
#    'to',
#    'see',
#    'her',
#    '.'],
#   ['angel',
#    'and',
#    'his',
#    'crew',
#    'did',
#    'an',
#    'amazing',
#    'job',
#    'on',
#    'our',
#    'outdoor',
#    'kitchen',
#    'project',
#    '!',
#    '!',
#    'they',
#    'were',
#    'patient',
#    'when',
#    'the',
#    'general',
#    'contractor',
#    'was',
#    'behind',
#    'schedule',
#    'and',
#    'stayed',
#    'in',
#    'contact',
#    'with',
#    'us',
#    'until',
#    'the',
#    'time',
#    'was',
#    'right',
#    '.',
#    'installation',
#    'was',
#    'perfect',
#    'and',
#    'they',
#    'nailed',
#    'the',
#    'waterfall',
#    'edge',
#    '.',
#    'many',
#    'people',
#    'can',
#    'not',
#    'believe',
#    'there',
#    'is',
#    'a',
#    'seam',
#    ',',
#    'its',
#    'flawless',
#    '!',
#    'we',
#    "'ll",
#    'definitely',
#    'use',
#    'them',
#    'again',
#    'and',
#    'tell',
#    'our',
#    'friends',
#    'and',
#    'family',
#    'about',
#    'vegas',
#    'granite',
#    '!'],
#   ['we',
#    'took',
#    'a',
#    'risk',
#    'and',
#    'picked',
#    'a',
#    'mexican',
#    'place',
#    'not',
#    'close',
#    'to',
#    'us',
#    'based',
#    'on',
#    'the',
#    'ratings',
#    'on',
#    'yelp',
#    '.',
#    'we',
#    'read',
#    'that',
#    'the',
#    'portions',
#    'were',
#    'good',
#    'and',
#    'the',
#    'flavor',
#    'was',
#    'too',
#    '.',
#    'we',
#    'were',
#    'not',
#    'disappointed',
#    '.',
#    'i',
#    'had',
#    'the',
#    'flag',
#    'enchiladas',
#    ',',
#    'a',
#    'great',
#    'mix',
#    'of',
#    'flavors',
#    ',',
#    'it',
#    'was',
#    'very',
#    'good',
#    '!',
#    'we',
#    'also',
#    'had',
#    'chips',
#    'and',
#    'salsa',
#    ',',
#    'not',
#    'my',
#    'favorite',
#    'but',
#    'decent',
#    '.',
#    'i',
#    'would',
#    'definitely',
#    'return',
#    '.'],
#   ['called',
#    'them',
#    'to',
#    'spray',
#    'off',
#    'the',
#    'leaves',
#    'and',
#    'bird',
#    'droppings',
#    'from',
#    'my',
#    'roof',
#    '.',
#    'great',
#    'job',
#    '.',
#    'same',
#    'day',
#    'quote',
#    '.',
#    'next',
#    'day',
#    'service',
#    '.',
#    'affordable',
#    'and',
#    'friendly',
#    '.'],
#   ['restaurant',
#    'was',
#    '3',
#    'quarters',
#    'full',
#    'and',
#    'we',
#    'were',
#    'seated',
#    'immediately',
#    '.',
#    'the',
#    'food',
#    'was',
#    'delicious',
#    'but',
#    'we',
#    'had',
#    'to',
#    'continuously',
#    'ask',
#    'for',
#    'items',
#    'and',
#    'we',
#    'were',
#    'missing',
#    'a',
#    'dish',
#    '.',
#    'seemed',
#    'like',
#    'they',
#    'were',
#    'low',
#    'on',
#    'staff',
#    '.',
#    'the',
#    'food',
#    'was',
#    'good',
#    'but',
#    'the',
#    'service',
#    'was',
#    "n't",
#    'too',
#    'great',
#    '.'],
#   ['let',
#    'me',
#    'start',
#    'off',
#    'by',
#    'saying',
#    'service',
#    'was',
#    'beyond',
#    'awesome',
#    'here',
#    '.',
#    'the',
#    'first',
#    'dish',
#    'i',
#    'ordered',
#    ',',
#    'i',
#    'did',
#    'not',
#    'realize',
#    'was',
#    'finished',
#    'in',
#    'the',
#    'pan',
#    ',',
#    'and',
#    'fried',
#    '.',
#    'i',
#    'hate',
#    'friend',
#    ',',
#    'or',
#    'pan',
#    'friend',
#    'fish',
#    'period',
#    '.',
#    'i',
#    'told',
#    'the',
#    'waiter',
#    'what',
#    'i',
#    'wanted',
#    '.',
#    'the',
#    'only',
#    'fish',
#    'they',
#    'had',
#    'not',
#    'friend',
#    'or',
#    'finished',
#    'in',
#    'the',
#    'pan',
#    'was',
#    'the',
#    'halibut',
#    '.',
#    'so',
#    'the',
#    'chef',
#    'made',
#    'a',
#    'special',
#    'halibut',
#    'dish',
#    'for',
#    'me',
#    'int',
#    'he',
#    'over',
#    'that',
#    'was',
#    'seriously',
#    ',',
#    'to',
#    'die',
#    'for',
#    '!'],
#   ['excellent',
#    'food',
#    ',',
#    'great',
#    'atmosphere',
#    ',',
#    'wonderful',
#    'service',
#    '!',
#    'i',
#    'grabbed',
#    'dinner',
#    'here',
#    'with',
#    'some',
#    'colleagues',
#    'after',
#    'a',
#    'conference',
#    ',',
#    'and',
#    'we',
#    'greatly',
#    'enjoyed',
#    'our',
#    'meal',
#    '.',
#    'howie',
#    'was',
#    'a',
#    'great',
#    'server',
#    ',',
#    'and',
#    'was',
#    'able',
#    'to',
#    'recommend',
#    'some',
#    'of',
#    'his',
#    'favorite',
#    'things',
#    'on',
#    'the',
#    'menu',
#    'to',
#    'our',
#    'indecisive',
#    'group',
#    '.',
#    'make',
#    'sure',
#    'to',
#    'save',
#    'room',
#    'for',
#    'the',
#    'peach',
#    'cobbler',
#    '!'],
#   ['i',
#    "'ve",
#    'been',
#    'searching',
#    'for',
#    'a',
#    'great',
#    'deal',
#    'on',
#    'a',
#    'leather',
#    'sectional',
#    'and',
#    'this',
#    'couch',
#    'is',
#    'exactly',
#    'what',
#    'i',
#    "'m",
#    'looking',
#    'for',
#    '!',
#    'ken',
#    'was',
#    'very',
#    'helpful',
#    'and',
#    'patient',
#    'listening',
#    'to',
#    'my',
#    'needs',
#    'and',
#    'what',
#    'would',
#    'work',
#    '.',
#    'he',
#    'is',
#    'easy',
#    'to',
#    'talk',
#    'to',
#    'and',
#    'knowledgeable',
#    'about',
#    'the',
#    'furniture',
#    '.',
#    'they',
#    'have',
#    'an',
#    'array',
#    'of',
#    'different',
#    'styles',
#    'and',
#    'he',
#    'can',
#    'order',
#    'them',
#    'promptly',
#    'and',
#    'pricing',
#    'is',
#    'affordable',
#    '.',
#    'i',
#    'am',
#    'very',
#    'happy',
#    'i',
#    'found',
#    'them',
#    '.',
#    'thank',
#    'you',
#    ',',
#    'ken',
#    '.'],
#   ['this',
#    'place',
#    'does',
#    'it',
#    'for',
#    'me',
#    '.',
#    '$',
#    '1.50',
#    'a',
#    'ticket',
#    'is',
#    'cool',
#    'they',
#    'always',
#    'have',
#    'family',
#    'shows',
#    'playing',
#    ',',
#    'my',
#    'kidz',
#    'love',
#    'it',
#    '.',
#    'six',
#    'of',
#    'us',
#    'for',
#    '9',
#    'bucks',
#    'you',
#    'ca',
#    'nt',
#    'beat',
#    'it',
#    '.',
#    'the',
#    'popcorn',
#    'is',
#    '$',
#    '5.25',
#    'for',
#    'a',
#    'large',
#    'with',
#    '1',
#    'refill',
#    'then',
#    'they',
#    'have',
#    'the',
#    'popcorn',
#    'seasoning',
#    'white',
#    'cheddar',
#    ',',
#    'ranch',
#    ',',
#    'jalapeno',
#    'cheddar',
#    ',',
#    'nacho',
#    'cheese',
#    '.',
#    'no',
#    'other',
#    'cinema',
#    'i',
#    "'ve",
#    'been',
#    'too',
#    'have',
#    'the',
#    'seasonings',
#    'soo',
#    '.',
#    '5',
#    'stars',
#    'from',
#    'me'],
#   ['very',
#    'good',
#    'food',
#    '.',
#    'however',
#    ',',
#    'bad',
#    'service',
#    '.',
#    'we',
#    'went',
#    'there',
#    'and',
#    'it',
#    'took',
#    'the',
#    'server',
#    'more',
#    'than',
#    '20',
#    'minutes',
#    'to',
#    'bring',
#    'the',
#    'men',
#    ',',
#    'we',
#    'actually',
#    'had',
#    'to',
#    'tell',
#    'him',
#    '"',
#    'hello',
#    'were',
#    'here',
#    '"',
#    '.',
#    'it',
#    'feels',
#    'like',
#    'the',
#    'staff',
#    'over',
#    'here',
#    'are',
#    'not',
#    'happy',
#    'with',
#    'their',
#    'work',
#    ',',
#    'and',
#    'they',
#    'try',
#    'to',
#    'get',
#    'this',
#    'out',
#    'on',
#    'customers',
#    '.'],
#   ['as',
#    'usual',
#    'this',
#    'buffet',
#    'does',
#    "n't",
#    'disappoint',
#    '.',
#    'the',
#    'gelato',
#    'is',
#    'awesome',
#    'as',
#    'well',
#    'as',
#    'the',
#    'cookies',
#    'we',
#    'had',
#    '.',
#    'the',
#    'food',
#    'is',
#    'really',
#    'good',
#    ',',
#    'except',
#    'for',
#    'a',
#    'few',
#    'things',
#    'we',
#    'had',
#    'were',
#    'ok',
#    '.',
#    'we',
#    'had',
#    'the',
#    'lunch',
#    'buffet',
#    'here',
#    '.',
#    'overall',
#    'is',
#    'was',
#    'a',
#    'very',
#    'good',
#    'experience',
#    '.'],
#   ['it',
#    "'s",
#    'like',
#    'a',
#    'panda',
#    'express',
#    'meets',
#    'any',
#    'of',
#    'the',
#    'taquerias',
#    'you',
#    'see',
#    'around',
#    'the',
#    'valley',
#    '.',
#    'the',
#    'jerk',
#    'chicken',
#    'is',
#    'my',
#    'personal',
#    'favorite',
#    'for',
#    'the',
#    'quesadillas',
#    'and',
#    'the',
#    'black',
#    'beans',
#    'are',
#    'a-1',
#    ',',
#    'would',
#    'slap',
#    'someone',
#    "'s",
#    'momma',
#    ',',
#    'just',
#    'not',
#    'mines',
#    '.',
#    'this',
#    'establishment',
#    'has',
#    'been',
#    'around',
#    'for',
#    'years',
#    'and',
#    'the',
#    'food',
#    'is',
#    'consistently',
#    'good',
#    '.'],
#   ['good',
#    'hookah',
#    'lounge',
#    '.',
#    'friendly',
#    'staff',
#    ',',
#    'wide',
#    'selection',
#    'of',
#    'hookah',
#    'flavours',
#    '.',
#    'nice',
#    'place',
#    'to',
#    'chillout',
#    '.'],
#   ['my',
#    'son',
#    'likes',
#    'to',
#    'go',
#    'because',
#    'of',
#    'the',
#    'cool',
#    'stuff',
#    '!',
#    'they',
#    'need',
#    'new',
#    'chairs',
#    'the',
#    'plastic',
#    'lawn',
#    'chairs',
#    'are',
#    'not',
#    'comfortable',
#    'if',
#    'you',
#    'have',
#    'to',
#    'sit',
#    'more',
#    'than',
#    '10',
#    'minutes',
#    '!',
#    'food',
#    'is',
#    'hit',
#    'or',
#    'miss',
#    'but',
#    'staff',
#    'is',
#    'usually',
#    'very',
#    'nice',
#    '.'],
#   ['the',
#    'observation',
#    'deck',
#    'is',
#    'great',
#    '.',
#    'my',
#    'young',
#    'children',
#    'were',
#    "n't",
#    'very',
#    'interested',
#    'but',
#    'that',
#    'could',
#    'be',
#    'because',
#    'they',
#    "'ve",
#    'been',
#    'ruined',
#    'by',
#    'the',
#    'willis',
#    'tower',
#    '.',
#    'but',
#    ',',
#    'i',
#    'love',
#    'cleveland',
#    '.',
#    'it',
#    "'s",
#    'beautiful',
#    '!',
#    'so',
#    ',',
#    'i',
#    'enjoyed',
#    'the',
#    'deck',
#    '.',
#    'the',
#    'food',
#    'court',
#    'is',
#    'nice',
#    ',',
#    'very',
#    'crowded',
#    '.',
#    'hard',
#    'rick',
#    'is',
#    'a',
#    'plus',
#    'at',
#    'this',
#    'mall',
#    '.',
#    'shopping',
#    'is',
#    'pretty',
#    'limited',
#    '.'],
#   ['definitely',
#    'worth',
#    'parking',
#    'here',
#    ',',
#    'especially',
#    'if',
#    'you',
#    "'re",
#    'traveling',
#    'over',
#    'any',
#    'period',
#    'of',
#    'time',
#    'in',
#    'cleveland',
#    'that',
#    'involves',
#    'snow',
#    'fall',
#    '(',
#    'november',
#    'to',
#    'like',
#    'april',
#    ')',
#    '.',
#    'get',
#    'in',
#    'on',
#    'their',
#    'member',
#    'rewards',
#    ',',
#    'and',
#    'they',
#    "'ll",
#    'send',
#    'you',
#    'a',
#    'card',
#    'that',
#    'you',
#    'can',
#    'insert',
#    'and',
#    'use',
#    'instead',
#    'of',
#    'taking',
#    'a',
#    'ticket',
#    'every',
#    'time',
#    'you',
#    'park',
#    '.',
#    'you',
#    'can',
#    'build',
#    'up',
#    'free',
#    'parking',
#    'with',
#    'your',
#    'stays',
#    '.',
#    'if',
#    'you',
#    'work',
#    'for',
#    'uh',
#    ',',
#    'sign',
#    'up',
#    'through',
#    'uh',
#    "'s",
#    'group',
#    'rates',
#    'and',
#    'it',
#    'saves',
#    'you',
#    'a',
#    'little',
#    'bit',
#    'of',
#    'money',
#    'to',
#    'boot',
#    '(',
#    'especially',
#    'if',
#    'you',
#    'stay',
#    'for',
#    'an',
#    'extended',
#    'period',
#    'of',
#    'time',
#    ')',
#    '.',
#    'perk',
#    'is',
#    'that',
#    'they',
#    'have',
#    'complimentary',
#    'water',
#    'as',
#    'your',
#    'leaving',
#    'and',
#    'i',
#    'wo',
#    "n't",
#    'have',
#    'to',
#    'worry',
#    'about',
#    'scrapping',
#    'my',
#    'car',
#    'when',
#    'i',
#    'come',
#    'back',
#    'from',
#    'a',
#    'winter',
#    'trip'],
#   ['luv',
#    'this',
#    'place',
#    ',',
#    'it',
#    'does',
#    "n't",
#    'look',
#    'like',
#    'much',
#    'from',
#    'outside',
#    'but',
#    'when',
#    'you',
#    'get',
#    'inside',
#    'the',
#    'atmosphere',
#    'is',
#    'entirely',
#    'different',
#    '.',
#    'it',
#    "'s",
#    'real',
#    'chill',
#    'and',
#    'everything',
#    'is',
#    'great',
#    'music',
#    ',',
#    'food',
#    ',',
#    'drinks',
#    'etc',
#    '.',
#    'i',
#    'absolutely',
#    'have',
#    'nothing',
#    'bad',
#    'to',
#    'say',
#    'about',
#    'this',
#    'place',
#    '.'],
#   ['use',
#    'caution',
#    'with',
#    'this',
#    'location----they',
#    'sold',
#    'me',
#    'a',
#    'clearly',
#    'used',
#    'product',
#    'as',
#    'new',
#    '--',
#    'i',
#    'did',
#    "n't",
#    'detect',
#    'this',
#    'until',
#    'i',
#    'got',
#    'home',
#    '---',
#    'they',
#    'agreed',
#    'to',
#    'replace',
#    '---',
#    'however',
#    'in',
#    'my',
#    'opinion',
#    'this',
#    'is',
#    'a',
#    'deceptive',
#    'and',
#    'innapropriate',
#    'business',
#    'practice',
#    '.',
#    'i',
#    'usually',
#    'shop',
#    'at',
#    'the',
#    'tatum',
#    'store',
#    '--',
#    'where',
#    'i',
#    'have',
#    'never',
#    'had',
#    'a',
#    'problem',
#    'before',
#    '---',
#    'so',
#    'for',
#    'me',
#    'i',
#    'am',
#    'only',
#    'going',
#    'to',
#    'tatum',
#    'from',
#    'now',
#    'on',
#    '.'],
#   ['wow',
#    '!',
#    'was',
#    'here',
#    'for',
#    'the',
#    'opening',
#    'concert',
#    '(',
#    'the',
#    'killers',
#    'with',
#    'wayne',
#    'newton',
#    ',',
#    'blue',
#    'men',
#    'group',
#    ',',
#    'showgirls',
#    ',',
#    'etc',
#    '.',
#    ')',
#    '.',
#    'there',
#    'were',
#    'performers',
#    'outside',
#    'the',
#    'arena',
#    'who',
#    'were',
#    'great',
#    '.',
#    'fast',
#    ',',
#    'easy',
#    'entrance',
#    'even',
#    'with',
#    'security',
#    'and',
#    'a',
#    'huge',
#    'crowd',
#    '.',
#    'entertainers',
#    'inside',
#    'before',
#    'the',
#    'concert',
#    '.',
#    'nice',
#    'bathrooms',
#    '.',
#    'good',
#    'merchandise',
#    'and',
#    'food',
#    '/',
#    'drink',
#    'sales',
#    'areas',
#    '.',
#    'the',
#    'seats',
#    'were',
#    'okay',
#    '.',
#    'decent',
#    'sight',
#    'lines',
#    'to',
#    'the',
#    'stage',
#    'with',
#    'two',
#    'large',
#    'screens',
#    '.',
#    'there',
#    'were',
#    'fireworks',
#    'outside',
#    'after',
#    'the',
#    'concert',
#    '.',
#    'fun',
#    'night',
#    '!',
#    'we',
#    'stayed',
#    'at',
#    'the',
#    'aria',
#    'so',
#    'we',
#    'could',
#    'walk',
#    'to',
#    'the',
#    'arena',
#    'since',
#    'parking',
#    'would',
#    'be',
#    'expensive',
#    'and',
#    'a',
#    'pain',
#    '.'],
#   ['hot',
#    'yoga',
#    'markham',
#    'still',
#    'one',
#    'of',
#    'my',
#    'favourite',
#    'studio',
#    '.',
#    'used',
#    'the',
#    'passport',
#    'to',
#    'prana',
#    'for',
#    'a',
#    'visit',
#    'in',
#    'one',
#    'of',
#    'the',
#    'hot',
#    'yoga',
#    'classes',
#    '.',
#    'nash',
#    'was',
#    'the',
#    'teacher',
#    'and',
#    'he',
#    'was',
#    'funny',
#    'and',
#    'lighthearted',
#    'and',
#    'everyone',
#    'seems',
#    'to',
#    'enjoyed',
#    'the',
#    'class',
#    '.',
#    'there',
#    'were',
#    'quite',
#    'a',
#    'few',
#    'first',
#    'timer',
#    'so',
#    'the',
#    'class',
#    'was',
#    'more',
#    'like',
#    'a',
#    'beginner',
#    'level',
#    '.',
#    'nash',
#    'was',
#    'really',
#    'helpful',
#    'going',
#    'all',
#    'around',
#    'and',
#    'helping',
#    'us',
#    'all',
#    'with',
#    'the',
#    'poses',
#    '.',
#    'ca',
#    "n't",
#    'wait',
#    'to',
#    'go',
#    'back',
#    'again',
#    'for',
#    'another',
#    'class',
#    '.'],
#   ['located',
#    'next',
#    'to',
#    'the',
#    'costco',
#    'near',
#    'woodbine',
#    '&',
#    'hwy',
#    '7',
#    '.',
#    'looks',
#    'like',
#    'lots',
#    'of',
#    'people',
#    'go',
#    'for',
#    'dim',
#    'sum',
#    'and',
#    'grocery',
#    'shopping',
#    'without',
#    'having',
#    'to',
#    'move',
#    'the',
#    'car',
#    '.',
#    'however',
#    ',',
#    'unless',
#    'you',
#    'take',
#    'advantage',
#    'of',
#    'their',
#    'early',
#    'bird',
#    'pricing',
#    '(',
#    'we',
#    'did',
#    'not',
#    ')',
#    ',',
#    'not',
#    'that',
#    'great',
#    'a',
#    'place',
#    'for',
#    'dim',
#    'sum',
#    '...',
#    'better',
#    'quality',
#    '/',
#    'price',
#    'choices',
#    'are',
#    'readily',
#    'available',
#    '.',
#    'our',
#    'party',
#    'of',
#    'four',
#    'paid',
#    '$',
#    '57',
#    'all',
#    'in',
#    'for',
#    '8',
#    'so',
#    '-',
#    'so',
#    'dim',
#    'sum',
#    'dishes',
#    'plus',
#    'a',
#    'noodle',
#    'plate',
#    '.'],
#   ['awesome',
#    'smoke',
#    'shop',
#    '!',
#    'ca',
#    "n't",
#    'say',
#    'any',
#    'bad',
#    'things',
#    'about',
#    'this',
#    'place',
#    '.',
#    'the',
#    'son',
#    'and',
#    'dad',
#    'are',
#    'really',
#    'nice',
#    'and',
#    'provide',
#    'great',
#    'customer',
#    'service',
#    '.',
#    'i',
#    'always',
#    'come',
#    'here',
#    'for',
#    'my',
#    'hookah',
#    'flavor',
#    'and',
#    'coal',
#    'and',
#    'will',
#    'continue',
#    'to',
#    'do',
#    'so',
#    '!'],
#   ['if',
#    'i',
#    'had',
#    'to',
#    'describe',
#    'this',
#    'show',
#    'in',
#    'one',
#    'word',
#    'it',
#    'would',
#    'be',
#    'energy',
#    '.',
#    'fortunately',
#    ',',
#    'i',
#    'have',
#    'enough',
#    'space',
#    'to',
#    'leave',
#    'a',
#    'full',
#    'review',
#    'here',
#    '!',
#    'jeff',
#    'civillico',
#    'has',
#    'the',
#    'most',
#    'energy',
#    'of',
#    'any',
#    'entertainer',
#    'i',
#    'have',
#    'known',
#    '.',
#    'he',
#    'spends',
#    'the',
#    'full',
#    'hour',
#    '+',
#    'show',
#    'running',
#    ',',
#    'juggling',
#    ',',
#    'and',
#    'even',
#    'unicycling',
#    ',',
#    'around',
#    'the',
#    'stage',
#    'while',
#    'being',
#    'hysterically',
#    'funny',
#    '.',
#    'he',
#    'is',
#    'not',
#    'afraid',
#    'to',
#    'take',
#    'chances',
#    'and',
#    'adds',
#    'new',
#    ',',
#    'innovative',
#    ',',
#    'tricks',
#    'and',
#    'ideas',
#    'to',
#    'his',
#    'show',
#    '(',
#    'such',
#    'as',
#    'the',
#    'go',
#    '-',
#    'pro',
#    'camera',
#    ',',
#    'his',
#    'giant',
#    'blow',
#    '-',
#    'up',
#    'set',
#    ',',
#    'a',
#    'tv',
#    'show',
#    'he',
#    'filmed',
#    'searching',
#    'for',
#    'unique',
#    'and',
#    'talented',
#    'entertainers',
#    ',',
#    'partnerships',
#    'and',
#    'promotions',
#    'of',
#    'fellow',
#    'entertainers',
#    '...',
#    ')',
#    '.',
#    'it',
#    'truly',
#    'is',
#    'a',
#    'must',
#    'see',
#    'show',
#    '...',
#    'you',
#    'never',
#    'knew',
#    'juggling',
#    'could',
#    'be',
#    'this',
#    'entertaining',
#    ',',
#    'until',
#    'you',
#    "'ve",
#    'seen',
#    'jeff',
#    "'s",
#    'show',
#    '.',
#    'i',
#    'have',
#    'seen',
#    'his',
#    'show',
#    'at',
#    'least',
#    '3',
#    'times',
#    'and',
#    'am',
#    'always',
#    'taking',
#    'family',
#    'and',
#    'friends',
#    'when',
#    'they',
#    'come',
#    'to',
#    'town',
#    '.',
#    'aside',
#    'from',
#    'the',
#    'show',
#    '-',
#    'jeff',
#    'has',
#    'a',
#    'great',
#    'talent',
#    'and',
#    'an',
#    'even',
#    'bigger',
#    'heart',
#    ',',
#    'giving',
#    'back',
#    'countless',
#    'hours',
#    'of',
#    'entertainment',
#    'and',
#    'donations',
#    '/',
#    'fundraisers',
#    'to',
#    'several',
#    'local',
#    'charities',
#    'on',
#    '-',
#    'stage',
#    'and',
#    'off',
#    '.',
#    'he',
#    'also',
#    'started',
#    'win',
#    '-',
#    'win',
#    'entertainment',
#    'to',
#    'partner',
#    'local',
#    'charities',
#    'with',
#    'celebrities',
#    'to',
#    'help',
#    'with',
#    'their',
#    'fundraising',
#    'efforts',
#    '.',
#    'he',
#    'is',
#    'highly',
#    'spoken',
#    'about',
#    'around',
#    'town',
#    'and',
#    'i',
#    'highly',
#    'encourage',
#    'you',
#    'to',
#    'support',
#    'this',
#    'great',
#    'entertainer',
#    'by',
#    'seeing',
#    'his',
#    'show',
#    '.',
#    'i',
#    'promise',
#    'you',
#    'wo',
#    "n't",
#    'be',
#    'sorry',
#    '.'],
#   ['i',
#    'ordered',
#    'the',
#    'standard',
#    'burger',
#    'and',
#    'my',
#    'husband',
#    'got',
#    'wild',
#    'boar',
#    'burger',
#    'with',
#    'fries',
#    'and',
#    'onion',
#    'rings',
#    '.',
#    'love',
#    'the',
#    'burgers',
#    'there',
#    'but',
#    'only',
#    'one',
#    'thing',
#    'is',
#    'i',
#    'should',
#    'have',
#    'ordered',
#    'medium',
#    'as',
#    'my',
#    'preference',
#    '.',
#    '(',
#    'their',
#    'red',
#    'meats',
#    'are',
#    'cooked',
#    'medium',
#    'well',
#    ')',
#    'we',
#    'definitely',
#    'want',
#    'to',
#    'go',
#    'back',
#    'to',
#    'try',
#    'elk',
#    'burger',
#    '.'],
#   ['i',
#    'always',
#    'come',
#    'here',
#    'when',
#    'i',
#    'come',
#    'to',
#    'vegas',
#    '!',
#    'instead',
#    'of',
#    'getting',
#    'a',
#    'dessert',
#    'crepe',
#    'i',
#    'got',
#    'a',
#    'savory',
#    'one',
#    'today',
#    '!',
#    'the',
#    'ham',
#    'and',
#    'cheese',
#    ',',
#    'but',
#    'i',
#    'wanted',
#    'breakfast',
#    'so',
#    'they',
#    'added',
#    'eggs',
#    'for',
#    'a',
#    '$',
#    '1.29',
#    '!',
#    'so',
#    'yummy',
#    '!',
#    '!',
#    '!'],
#   ['i',
#    'really',
#    'enjoy',
#    'coming',
#    'to',
#    'this',
#    'place',
#    '.',
#    'it',
#    'is',
#    'my',
#    'go',
#    'to',
#    'thai',
#    'place',
#    '.',
#    'their',
#    'curries',
#    'are',
#    'amazing',
#    'and',
#    'they',
#    'give',
#    'plenty',
#    'of',
#    'portions',
#    '.',
#    'as',
#    'for',
#    'their',
#    'thai',
#    'tea',
#    ',',
#    'it',
#    'is',
#    'one',
#    'of',
#    'the',
#    'best',
#    'i',
#    "'ve",
#    'had',
#    '.',
#    'i',
#    'recommend',
#    'this',
#    'place',
#    'for',
#    'sure',
#    '!'],
#   ['cliff',
#    'has',
#    'been',
#    'a',
#    'barber',
#    'for',
#    'years',
#    'so',
#    'he',
#    'knows',
#    'what',
#    'he',
#    "'s",
#    'doing',
#    '.',
#    'he',
#    'is',
#    'very',
#    'amiable',
#    '.',
#    'the',
#    'price',
#    'is',
#    'right',
#    '(',
#    '$',
#    '14',
#    ')',
#    'and',
#    'he',
#    'opens',
#    'early',
#    '(',
#    '6:30',
#    ')',
#    'so',
#    'you',
#    'can',
#    'stop',
#    'by',
#    'on',
#    'your',
#    'way',
#    'to',
#    'work',
#    '.',
#    'open',
#    'we',
#    'd',
#    '-',
#    'sat',
#    '.',
#    'great',
#    'haircut',
#    'too',
#    '.'],
#   ['the',
#    'panang',
#    'and',
#    'chicken',
#    'curry',
#    'are',
#    'delicious',
#    '.',
#    'the',
#    'dragon',
#    'eggs',
#    'are',
#    'original',
#    'and',
#    'i',
#    'like',
#    'their',
#    'green',
#    'tea',
#    '.',
#    'unfortunately',
#    'the',
#    'service',
#    'is',
#    'really',
#    'lacking',
#    '.',
#    'we',
#    'were',
#    'here',
#    'on',
#    'a',
#    'non',
#    'busy',
#    'night',
#    'and',
#    'the',
#    'table',
#    'service',
#    'was',
#    'very',
#    'slow',
#    '.',
#    'it',
#    'was',
#    'disappointing',
#    'especially',
#    'for',
#    'a',
#    'restaurant',
#    'that',
#    'made',
#    'diners',
#    'drive',
#    '-',
#    'ins',
#    'and',
#    'dives',
#    '.']]}

# %% [markdown]
# #### We store the useful data:

# %% [markdown]
# The useful data is a list of dictionnaries with 5 fields:
#
# | Name Of Field | percentage_correct_pred                        | label                           | prediction                                   | attention                                       | text                    |
# |---------------|------------------------------------------------|---------------------------------|----------------------------------------------|-------------------------------------------------|-------------------------|
# | Type          | float                                          | list of ints                    | list of ints                                 | list of floats                                  | list of list of strings |
# | Desc          | Percentage of correct prediction on this batch | The true rating for each review | The prediction of the rating for each review | The value of the attention matrix for the batch | The reviews in text     |

# %%
np.save("content/useful_data.npy", useful_data)

# %% [markdown]
# ## Creating the heatmap:
#
# #### You can directly load the data if you already created it:

# %%
# If dir content does not exist, we create it
dir_name = "content/"
if(not os.path.exists(dir_name)):
    os.makedirs(dir_name)
    print("Created directory named {}".format(dir_name))
else:
    print("You already got a content directory!")
    

useful_data_path = dir_name + "useful_data.npy"
useful_data_exists = os.path.exists(useful_data_path)

if(useful_data_exists):
    useful_data = np.load(useful_data_path, allow_pickle=True)
    arg_max_pred = np.argmax(percentage)
    print("We successfully loaded the data!")
else:
    print("You do not have the data, you must execute the cells above!")
# Out:
# You already got a content directory!
# We successfully loaded the data!

# %%
useful_data[arg_max_pred]
# Out:
# {'percentage_correct_pred': 0.86,
#  'prediction': array([4, 4, 0, 4, 3, 4, 3, 4, 4, 4, 4, 4, 3, 4, 4, 4, 4, 4, 3, 4, 2, 0,
#         4, 4, 3, 4, 2, 4, 4, 4, 4, 1, 3, 3, 3, 3, 4, 4, 4, 0, 4, 4, 2, 4,
#         4, 3, 4, 4, 4, 2]),
#  'label': array([4, 0, 1, 4, 3, 4, 3, 4, 4, 4, 4, 4, 3, 4, 4, 3, 4, 4, 3, 4, 2, 0,
#         4, 4, 3, 4, 2, 4, 4, 4, 4, 2, 3, 3, 3, 3, 4, 4, 4, 0, 3, 2, 1, 4,
#         4, 3, 4, 4, 4, 2]),
#  'attention': array([[[6.9479982e-17, 3.7688202e-19, 2.4956808e-18, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.1756009e-10, 3.4919123e-11, 1.5651160e-10, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [8.4452915e-07, 7.5302398e-07, 4.4834234e-08, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [5.3873210e-18, 6.6278105e-17, 6.9929129e-18, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         [[5.4496979e-23, 1.4840667e-24, 2.5505597e-24, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.8656176e-16, 3.2612792e-19, 3.2086960e-20, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [7.0425165e-14, 2.4650541e-15, 2.6286839e-16, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.7522340e-24, 3.3445354e-21, 3.3099383e-20, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         [[7.8695925e-17, 2.2612814e-18, 8.6848981e-17, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.5426380e-23, 3.4478911e-21, 1.6568497e-20, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [9.8925734e-10, 2.6140927e-09, 1.3622234e-10, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.6449690e-07, 9.4680963e-10, 6.5627975e-11, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         ...,
#
#         [[7.2191480e-17, 3.1372791e-12, 1.0000000e+00, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [6.8874823e-17, 8.2922118e-18, 4.1562200e-23, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.0266489e-12, 2.7697115e-12, 3.2145783e-11, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [4.4385027e-16, 1.1791004e-16, 2.3181712e-13, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         [[2.1600027e-16, 5.5251471e-18, 1.2322599e-15, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [8.8369268e-12, 1.1934034e-07, 1.4186833e-06, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [2.4364141e-07, 4.3096370e-06, 1.2143711e-08, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [2.3413945e-06, 9.1044651e-11, 1.2275124e-12, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#         [[9.6306538e-20, 5.9224961e-17, 6.0392485e-21, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [2.4303330e-15, 3.1838949e-22, 5.1195282e-21, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [1.1787088e-10, 1.5206451e-10, 5.8838501e-05, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#          [6.5432452e-08, 6.6552025e-01, 2.9426348e-01, ...,
#           0.0000000e+00, 0.0000000e+00, 0.0000000e+00]]], dtype=float32),
#  'text': [['i',
#    'have',
#    'been',
#    'going',
#    'here',
#    'for',
#    'about',
#    'a',
#    'year',
#    '.',
#    'i',
#    'bring',
#    'my',
#    'daughter',
#    'as',
#    'well',
#    '.',
#    'they',
#    'do',
#    'an',
#    'excellent',
#    'job',
#    'every',
#    'time',
#    '.',
#    'i',
#    'usually',
#    'ask',
#    'for',
#    'lilly',
#    '.',
#    'she',
#    'is',
#    'awesome',
#    '.',
#    'i',
#    "'ve",
#    'never',
#    'seen',
#    'rudeness',
#    '.',
#    'true',
#    'they',
#    'do',
#    'get',
#    'very',
#    'busy',
#    '.',
#    'but',
#    'that',
#    'shows',
#    'how',
#    'good',
#    'they',
#    'are',
#    '.'],
#   ['i',
#    'have',
#    'to',
#    'say',
#    'that',
#    'i',
#    'was',
#    'just',
#    'appalled',
#    'by',
#    'the',
#    'attendants',
#    'in',
#    'the',
#    'show',
#    '.',
#    'this',
#    'was',
#    'a',
#    'very',
#    'fun',
#    'loud',
#    'amazing',
#    'show',
#    'and',
#    'everyone',
#    'was',
#    'dancing',
#    'and',
#    'clapping',
#    'and',
#    'singing',
#    'along',
#    'to',
#    'the',
#    'show',
#    '.',
#    'why',
#    'my',
#    'self',
#    ',',
#    'partner',
#    ',',
#    'and',
#    'best',
#    'friend',
#    'was',
#    'pin',
#    'pointed',
#    'out',
#    'as',
#    'being',
#    'to',
#    'loud',
#    'is',
#    'beyond',
#    'me',
#    '.',
#    'it',
#    "'s",
#    'sad',
#    'to',
#    'say',
#    'i',
#    'will',
#    'never',
#    'go',
#    'back',
#    'even',
#    'though',
#    'the',
#    'show',
#    'was',
#    'amazing',
#    '.',
#    'i',
#    'felt',
#    'discriminated',
#    'and',
#    'humiliated',
#    'that',
#    'they',
#    'can',
#    'dismiss',
#    'us',
#    'from',
#    'a',
#    'show',
#    'for',
#    'being',
#    'too',
#    'loud',
#    '.',
#    'i',
#    'am',
#    'a',
#    '45',
#    'year',
#    'old',
#    'woman',
#    'and',
#    'my',
#    'partner',
#    'is',
#    '55',
#    'and',
#    'you',
#    'are',
#    'really',
#    'going',
#    'to',
#    'kick',
#    'us',
#    'out',
#    'like',
#    'we',
#    'were',
#    'little',
#    'kids',
#    'that',
#    'would',
#    "n't",
#    'behave',
#    '..',
#    'i',
#    'am',
#    'not',
#    'al',
#    'all',
#    'a',
#    'negative',
#    'person',
#    'but',
#    'this',
#    'was',
#    'way',
#    'out',
#    'of',
#    'line',
#    'and',
#    'uncalled',
#    'for',
#    '.'],
#   ['new',
#    'in',
#    'town',
#    '&',
#    'this',
#    'place',
#    'was',
#    'recommended',
#    'to',
#    'my',
#    'husband',
#    'and',
#    'i',
#    'by',
#    'many',
#    'people',
#    '.',
#    'we',
#    'are',
#    'both',
#    'from',
#    'ca',
#    ',',
#    'so',
#    'we',
#    'know',
#    'good',
#    'mexican',
#    'food',
#    '.',
#    'we',
#    'have',
#    'been',
#    'living',
#    'in',
#    'italy',
#    'for',
#    'the',
#    'past',
#    'few',
#    'years',
#    ',',
#    'where',
#    'mexican',
#    'food',
#    'is',
#    'non',
#    '-',
#    'existent',
#    ',',
#    'so',
#    'we',
#    'were',
#    'looking',
#    'forward',
#    'to',
#    'eating',
#    'here',
#    '.',
#    'i',
#    'got',
#    'the',
#    '1',
#    'taco',
#    '&',
#    '1',
#    'enchilada',
#    'plate',
#    '&',
#    'my',
#    'husband',
#    'got',
#    'the',
#    '1',
#    'burrito',
#    '&',
#    '1',
#    'enchilada',
#    'plate',
#    '.',
#    'while',
#    'eating',
#    'the',
#    'beans',
#    'i',
#    'was',
#    'thinking',
#    'to',
#    'myself',
#    'how',
#    'salty',
#    'they',
#    'were',
#    ',',
#    '&',
#    'then',
#    'moved',
#    'on',
#    'to',
#    'the',
#    'taco',
#    'which',
#    'was',
#    'even',
#    'more',
#    'salty',
#    '.',
#    'it',
#    'tasted',
#    'like',
#    'i',
#    'was',
#    'eating',
#    'pure',
#    'salt',
#    '.',
#    'i',
#    'mentioned',
#    'it',
#    'to',
#    'my',
#    'husband',
#    ',',
#    '&',
#    'he',
#    'said',
#    'the',
#    'same',
#    'thing',
#    '.',
#    'needless',
#    'to',
#    'say',
#    ',',
#    'we',
#    'did',
#    'not',
#    'finish',
#    'our',
#    'food',
#    '.',
#    'will',
#    'not',
#    'be',
#    'eating',
#    'here',
#    'again',
#    '.'],
#   ['this',
#    'one',
#    'of',
#    'my',
#    'favorite',
#    'dining',
#    'experiences',
#    'ever',
#    '.',
#    'i',
#    'really',
#    'loved',
#    'the',
#    'adventure',
#    'and',
#    'mystery',
#    'of',
#    'the',
#    'whole',
#    'thing',
#    '.',
#    'it',
#    'was',
#    'a',
#    'fun',
#    'challenge',
#    'to',
#    'guess',
#    'food',
#    'and',
#    'an',
#    'even',
#    'more',
#    'interesting',
#    'one',
#    'to',
#    'try',
#    'and',
#    'use',
#    'utensils',
#    'in',
#    'the',
#    'dark',
#    '.',
#    'i',
#    "'d",
#    'highly',
#    'recommend',
#    'this',
#    'to',
#    'anybody',
#    'looking',
#    'for',
#    'an',
#    'out',
#    'of',
#    'the',
#    'box',
#    'dinner',
#    '.',
#    'you',
#    'really',
#    'ca',
#    "n't",
#    'see',
#    'anything',
#    'in',
#    'there',
#    ',',
#    'it',
#    "'s",
#    'pitch',
#    'black',
#    '.',
#    'although',
#    'sometimes',
#    'you',
#    'can',
#    'see',
#    'the',
#    'infrared',
#    'goggles',
#    'of',
#    'the',
#    'waiter',
#    'or',
#    'waitress',
#    'if',
#    'they',
#    "'re",
#    'looking',
#    'directly',
#    'at',
#    'you',
#    '.'],
#   ['my',
#    'hubby',
#    'and',
#    'i',
#    'stayed',
#    'at',
#    'the',
#    'venetian',
#    'during',
#    'the',
#    'week',
#    'last',
#    'week',
#    '.',
#    'the',
#    'price',
#    'was',
#    'great',
#    '(',
#    '169/night',
#    ')',
#    'with',
#    'a',
#    'package',
#    'that',
#    'included',
#    '$',
#    '40',
#    'off',
#    'the',
#    'phantom',
#    'of',
#    'the',
#    'opera',
#    'show',
#    'tickets',
#    '!',
#    'we',
#    'were',
#    'definitely',
#    'planning',
#    'on',
#    'seeing',
#    'it',
#    ',',
#    'so',
#    'it',
#    'was',
#    'perfect',
#    '!',
#    'there',
#    'were',
#    'other',
#    'discounts',
#    'in',
#    'the',
#    'package',
#    '(',
#    'to',
#    'an',
#    'asian',
#    'restaurant',
#    'and',
#    'a',
#    'mexican',
#    'one',
#    'at',
#    'palazzo',
#    ')',
#    'but',
#    'we',
#    'did',
#    "n't",
#    'use',
#    'those',
#    '.',
#    'the',
#    'venetian',
#    '...',
#    'omg',
#    ',',
#    'i',
#    'loved',
#    'that',
#    'place',
#    '!',
#    'the',
#    'perfume',
#    'scent',
#    'that',
#    'others',
#    'complain',
#    'about',
#    'in',
#    'their',
#    'reviews',
#    ',',
#    'actually',
#    'was',
#    "n't",
#    'bad',
#    '...',
#    'i',
#    'was',
#    'worried',
#    'about',
#    'it',
#    ',',
#    'being',
#    'highly',
#    'allergic',
#    'to',
#    'strong',
#    'smelling',
#    'perfumes',
#    ',',
#    'but',
#    'it',
#    'was',
#    'actually',
#    'really',
#    'nice',
#    '...',
#    'i',
#    'even',
#    'miss',
#    'it',
#    'now',
#    '...',
#    'i',
#    'did',
#    "n't",
#    'sneeze',
#    'at',
#    'all',
#    'from',
#    'it',
#    '.',
#    'we',
#    'arrived',
#    'early',
#    ',',
#    '2',
#    'pm',
#    ',',
#    'and',
#    'they',
#    'checked',
#    'is',
#    'in',
#    'no',
#    'problem',
#    '(',
#    '3',
#    'pm',
#    'is',
#    'checkin)',
#    '...',
#    'our',
#    'room',
#    'was',
#    'very',
#    '-',
#    'very',
#    'nice',
#    ',',
#    'my',
#    'hubby',
#    "'s",
#    'jaw',
#    'sort',
#    'of',
#    'dropped',
#    'when',
#    'he',
#    'first',
#    'saw',
#    'the',
#    'room',
#    '(',
#    'i',
#    'booked',
#    'the',
#    'whole',
#    'thing',
#    'so',
#    'i',
#    'already',
#    'saw',
#    'the',
#    'pictures',
#    ')',
#    '.',
#    'it',
#    'was',
#    'very',
#    'spacious',
#    ',',
#    'from',
#    'the',
#    'bathroom',
#    'to',
#    'the',
#    'bedroom',
#    '/',
#    'living',
#    'room',
#    '...',
#    '3',
#    'tvs',
#    'in',
#    'the',
#    'place',
#    '!',
#    'i',
#    'subtracted',
#    'a',
#    'star',
#    'though',
#    'b',
#    '/',
#    'c',
#    'our',
#    'tv',
#    'in',
#    'the',
#    'bathroom',
#    'did',
#    'not',
#    'work',
#    ':(',
#    'i',
#    'was',
#    'bummed',
#    'b',
#    '/',
#    'c',
#    'being',
#    'a',
#    'woman',
#    'i',
#    'spend',
#    'a',
#    'lotta',
#    'time',
#    'in',
#    'there',
#    ':)',
#    'the',
#    'pool',
#    'area',
#    'on',
#    'the',
#    '4th',
#    'floor',
#    'was',
#    'very',
#    'nice',
#    '(',
#    'there',
#    "'s",
#    'another',
#    'pool',
#    'with',
#    'more',
#    'shade',
#    'and',
#    'more',
#    'privacy',
#    'on',
#    'the',
#    '10th',
#    'floor',
#    'too)',
#    '...',
#    'i',
#    'did',
#    "n't",
#    'check',
#    'out',
#    'tao',
#    'beach',
#    ',',
#    'because',
#    'i',
#    'did',
#    'nt',
#    'even',
#    'realize',
#    'that',
#    'was',
#    'in',
#    'a',
#    'different',
#    'area',
#    'until',
#    'later',
#    '.',
#    'my',
#    'hubby',
#    'walked',
#    'by',
#    'it',
#    'and',
#    'said',
#    'it',
#    'was',
#    'nothing',
#    'major',
#    ',',
#    'so',
#    'i',
#    'believed',
#    'him',
#    '.',
#    'there',
#    'were',
#    'sufficient',
#    'chairs',
#    'at',
#    'the',
#    'pool',
#    ',',
#    'and',
#    'the',
#    'waitresses',
#    'came',
#    'by',
#    'occasionally',
#    'to',
#    'see',
#    'if',
#    'anyone',
#    'needed',
#    'drinks',
#    '.',
#    'they',
#    'could',
#    "'ve",
#    'made',
#    'more',
#    'money',
#    'personally',
#    'if',
#    'they',
#    'came',
#    'by',
#    'more',
#    'frequently',
#    '.',
#    'drinks',
#    'were',
#    'good',
#    ',',
#    'and',
#    'the',
#    'restaurant',
#    '(',
#    'riva',
#    'by',
#    'wolfgang',
#    'puck',
#    ')',
#    'has',
#    'really',
#    'good',
#    'lunch',
#    'menu',
#    '(',
#    'pizza',
#    'was',
#    'great',
#    ',',
#    'and',
#    'their',
#    'salads',
#    'too',
#    ')',
#    '.',
#    'overall',
#    ',',
#    'next',
#    'time',
#    'i',
#    "'m",
#    'in',
#    'vegas',
#    'i',
#    'will',
#    'definitely',
#    'stay',
#    'at',
#    'the',
#    'venetian',
#    '.'],
#   ['we',
#    'had',
#    'a',
#    'long',
#    'wait',
#    'for',
#    'our',
#    'food',
#    ',',
#    'but',
#    'it',
#    'was',
#    'worth',
#    'it',
#    '!',
#    'the',
#    'waiter',
#    'was',
#    'terrific',
#    ',',
#    'even',
#    'with',
#    'our',
#    'large',
#    'group',
#    '.',
#    'i',
#    'ordered',
#    'the',
#    'children',
#    "'s",
#    'size',
#    'spaghetti',
#    ',',
#    'which',
#    'he',
#    'probably',
#    'thought',
#    'was',
#    'for',
#    'my',
#    '3-year',
#    'old',
#    '-',
#    'granddaughter',
#    ',',
#    'and',
#    'it',
#    'was',
#    'the',
#    'perfect',
#    'size',
#    'for',
#    'me',
#    '!',
#    'if',
#    'you',
#    'do',
#    "n't",
#    'want',
#    'to',
#    'wait',
#    'for',
#    'hours',
#    ',',
#    'consider',
#    'going',
#    'early',
#    'in',
#    'the',
#    'evening',
#    '!'],
#   ['there',
#    "'s",
#    'not',
#    'much',
#    'choice',
#    'in',
#    'pickering',
#    'when',
#    'you',
#    'want',
#    'something',
#    'with',
#    'good',
#    'food',
#    'and',
#    'a',
#    'great',
#    'view',
#    '.',
#    'i',
#    'had',
#    'never',
#    'even',
#    'heard',
#    'of',
#    'the',
#    'port',
#    ';',
#    'my',
#    'wife',
#    'and',
#    'i',
#    'were',
#    'given',
#    'a',
#    'gift',
#    'card',
#    'for',
#    'this',
#    'restaurant',
#    'with',
#    'a',
#    'car',
#    'purchase',
#    '.',
#    'as',
#    'it',
#    "'s",
#    'just',
#    'around',
#    'the',
#    'corner',
#    'from',
#    'us',
#    ',',
#    'we',
#    'decided',
#    'to',
#    'walk',
#    'there',
#    'for',
#    'dinner',
#    'and',
#    'have',
#    'a',
#    'few',
#    'drinks',
#    ',',
#    'too',
#    '.',
#    'once',
#    'through',
#    'the',
#    'front',
#    'door',
#    ',',
#    'it',
#    'was',
#    'almost',
#    'as',
#    'if',
#    'we',
#    "'d",
#    'walked',
#    'into',
#    'any',
#    'of',
#    'a',
#    'number',
#    'of',
#    'downtown',
#    'restaurants',
#    '.',
#    'the',
#    'decor',
#    'was',
#    'open',
#    'and',
#    'modern',
#    ',',
#    'and',
#    'the',
#    'music',
#    'was',
#    'unobtrusive',
#    '"',
#    'hip',
#    '"',
#    'dining',
#    'music',
#    '.',
#    '(',
#    'somewhat',
#    'electronic',
#    ',',
#    'with',
#    'nothing',
#    'at',
#    'all',
#    'to',
#    'catch',
#    'your',
#    'attention',
#    'either',
#    'positively',
#    'or',
#    'negatively',
#    '.',
#    'there',
#    'must',
#    'be',
#    'a',
#    'small',
#    'fortune',
#    'in',
#    'making',
#    'this',
#    'modern',
#    'take',
#    'on',
#    'musak',
#    '.',
#    ')',
#    'we',
#    'were',
#    'offered',
#    'a',
#    'seat',
#    'in',
#    'the',
#    'lounge',
#    'as',
#    'the',
#    'dining',
#    'room',
#    'was',
#    'full',
#    '.',
#    'we',
#    'sat',
#    'by',
#    'the',
#    'fireplace',
#    'which',
#    'was',
#    'nice',
#    '.',
#    'through',
#    'the',
#    'window',
#    'we',
#    'saw',
#    'a',
#    'great',
#    'patio',
#    'on',
#    'frenchman',
#    "'s",
#    'bay',
#    'which',
#    'will',
#    'be',
#    'a',
#    'definite',
#    'hang',
#    '-',
#    'out',
#    'for',
#    'us',
#    'this',
#    'summer',
#    '!',
#    'we',
#    'started',
#    'with',
#    'drinks',
#    'which',
#    'were',
#    'very',
#    'reasonably',
#    'priced',
#    '.',
#    '(',
#    'five',
#    'bucks',
#    'for',
#    'a',
#    'bottle',
#    'of',
#    'steamwhistle',
#    '?',
#    '!',
#    'maybe',
#    'moving',
#    'to',
#    'the',
#    'suburbs',
#    'does',
#    'have',
#    'it',
#    "'s",
#    'benefits',
#    '!',
#    '!',
#    '!',
#    ')',
#    'we',
#    'also',
#    'got',
#    'a',
#    'small',
#    'dish',
#    'of',
#    'spiced',
#    'olives',
#    'to',
#    'nibble',
#    'at',
#    'while',
#    'we',
#    'waited',
#    '.',
#    'the',
#    'staff',
#    'was',
#    'friendly',
#    ',',
#    'competent',
#    'and',
#    'efficient',
#    ',',
#    'and',
#    'they',
#    'all',
#    'seemed',
#    'to',
#    'be',
#    'working',
#    'hard',
#    'and',
#    'cheerfully',
#    '.',
#    'i',
#    'ordered',
#    'the',
#    'free',
#    'range',
#    'chicken',
#    'and',
#    'my',
#    'wife',
#    'ordered',
#    'the',
#    'salmon',
#    '.',
#    'chicken',
#    ':',
#    'a',
#    'breast',
#    'of',
#    'free',
#    'range',
#    'chicken',
#    'roasted',
#    'with',
#    'comfort',
#    'cream',
#    'cheese',
#    'and',
#    'topped',
#    'with',
#    'onion',
#    'marmalade',
#    ',',
#    'served',
#    'with',
#    'a',
#    'port',
#    'poached',
#    'pear',
#    'and',
#    'finished',
#    'with',
#    'wine',
#    'syrup',
#    'and',
#    'sage',
#    'aioli',
#    '.',
#    'this',
#    'dish',
#    'was',
#    'absolutely',
#    'fantastic',
#    '.',
#    'the',
#    'harmony',
#    'of',
#    'these',
#    'five',
#    'ingredients',
#    'was',
#    'just',
#    'wonderful',
#    '.',
#    'every',
#    'bite',
#    'was',
#    'something',
#    'special',
#    'and',
#    'i',
#    'thoroughly',
#    'enjoyed',
#    'this',
#    'dish',
#    '.',
#    'the',
#    'sweet',
#    'pear',
#    'and',
#    'the',
#    'savory',
#    'sage',
#    'aioli',
#    'were',
#    'a',
#    'beautiful',
#    'combination',
#    ',',
#    'the',
#    'chicken',
#    'was',
#    'moist',
#    'and',
#    'cooked',
#    'perfectly',
#    ',',
#    'and',
#    'the',
#    'wine',
#    'syrup',
#    'added',
#    'a',
#    'very',
#    'pleasing',
#    'bright',
#    'note',
#    '.',
#    'i',
#    'would',
#    'order',
#    'it',
#    'again',
#    'in',
#    'a',
#    'heartbeat',
#    '.',
#    'the',
#    'applewood',
#    'cheddar',
#    'mashed',
#    'potatoes',
#    'were',
#    'also',
#    'excellent',
#    ',',
#    'with',
#    'the',
#    'cheddar',
#    'adding',
#    'a',
#    'nicely',
#    'muted',
#    'sharpness',
#    'to',
#    'the',
#    'potato',
#    '.',
#    'the',
#    'other',
#    'seasonal',
#    'vegetables',
#    'were',
#    'asparagus',
#    ',',
#    'not',
#    'overcooked',
#    ',',
#    'and',
#    'possibly',
#    'the',
#    'best',
#    'mashed',
#    'turnip',
#    'i',
#    "'ve",
#    'ever',
#    'had',
#    '.',
#    'salmon',
#    ':',
#    'this',
#    'is',
#    'a',
#    'wasabi',
#    '-',
#    'pea',
#    'encrusted',
#    'salmon',
#    'on',
#    'a',
#    'bed',
#    'of',
#    'basmati',
#    'rice',
#    'and',
#    'vegetables',
#    '.',
#    'i',
#    'did',
#    "n't",
#    'try',
#    'the',
#    'vegetables',
#    'but',
#    'they',
#    'included',
#    'soy',
#    'glazed',
#    'water',
#    'chestnut',
#    ',',
#    'baby',
#    'corn',
#    '(',
#    'which',
#    'always',
#    'fails',
#    'to',
#    'impress',
#    'me',
#    'as',
#    'they',
#    'often',
#    'look',
#    'like',
#    'something',
#    'taken',
#    'straight',
#    'from',
#    'a',
#    'can',
#    'and',
#    'put',
#    'on',
#    'a',
#    'cheap',
#    'salad',
#    'bar',
#    ')',
#    ',',
#    'bamboo',
#    'shoots',
#    ',',
#    'hearts',
#    'of',
#    'palm',
#    'and',
#    'bok',
#    'choi',
#    '.',
#    'i',
#    'tasted',
#    'the',
#    'salmon',
#    'and',
#    'the',
#    'wasabi',
#    'that',
#    'encrusted',
#    'the',
#    'top',
#    'of',
#    'the',
#    'fish',
#    'was',
#    'a',
#    'very',
#    'nice',
#    'touch',
#    '.',
#    'she',
#    'said',
#    'she',
#    'enjoyed',
#    'the',
#    'dish',
#    'a',
#    'lot',
#    'but',
#    'was',
#    'a',
#    'little',
#    'underwhelmed',
#    'with',
#    'the',
#    'vegetables',
#    '.',
#    'they',
#    'were',
#    'good',
#    ',',
#    'but',
#    'nothing',
#    'too',
#    'special',
#    '.',
#    'after',
#    'another',
#    'round',
#    'of',
#    'steamwhistles',
#    ',',
#    'we',
#    'decided',
#    'to',
#    'order',
#    'a',
#    'nightcap',
#    'and',
#    'head',
#    'home',
#    '.',
#    'i',
#    'had',
#    'a',
#    'maker',
#    "'s",
#    'mark',
#    ',',
#    'she',
#    'had',
#    'a',
#    'bluberri',
#    'stoli',
#    '.',
#    'and',
#    'here',
#    "'s",
#    'the',
#    'kicker',
#    ':',
#    'a',
#    'small',
#    'appetizer',
#    ',',
#    'four',
#    'decent',
#    'beers',
#    ',',
#    'two',
#    'great',
#    'meals',
#    ',',
#    'and',
#    'two',
#    'final',
#    'drinks',
#    '......',
#    'under',
#    'a',
#    'hundred',
#    'bucks',
#    'including',
#    'tax',
#    '(',
#    'before',
#    'tip',
#    ')',
#    '.',
#    'at',
#    'that',
#    'price',
#    ',',
#    'for',
#    'that',
#    'quality',
#    ',',
#    'tipping',
#    'is',
#    'a',
#    'pleasure',
#    '!',
#    'we',
#    'will',
#    'definitely',
#    'be',
#    'returning',
#    ',',
#    'often',
#    '.'],
#   ['we',
#    'love',
#    'the',
#    'thumb',
#    ',',
#    'come',
#    'to',
#    'get',
#    'our',
#    'car',
#    'washed',
#    'and',
#    'have',
#    'breakfast',
#    'or',
#    'lunch',
#    'or',
#    'dinner',
#    ',',
#    'just',
#    'depending',
#    'on',
#    'the',
#    'time',
#    'of',
#    'the',
#    'day',
#    '.',
#    'the',
#    'brisket',
#    'sandwich',
#    'is',
#    'the',
#    'best',
#    'there',
#    'is',
#    '(',
#    'or',
#    'anything',
#    'with',
#    'brisket',
#    '!',
#    '!',
#    ')',
#    '.',
#    'the',
#    'fries',
#    'are',
#    'just',
#    'the',
#    'right',
#    'amount',
#    'of',
#    'crisp',
#    '.',
#    'staff',
#    'is',
#    'great',
#    ',',
#    'especially',
#    'the',
#    'car',
#    'wash',
#    'staff',
#    'who',
#    'do',
#    'an',
#    'awesome',
#    'and',
#    'consistent',
#    'job',
#    '.',
#    'looking',
#    'forward',
#    'to',
#    'enjoying',
#    'the',
#    'newly',
#    'remodeled',
#    'patio',
#    'this',
#    'fall',
#    '!'],
#   ['i',
#    'ordered',
#    'the',
#    'akropolis',
#    'pizza',
#    'and',
#    'pork',
#    'gyro',
#    '.',
#    'the',
#    'first',
#    'thing',
#    'i',
#    'noticed',
#    'when',
#    'the',
#    'pizza',
#    'came',
#    'out',
#    'was',
#    'how',
#    'vibrant',
#    'the',
#    'toppings',
#    'were',
#    '!',
#    'you',
#    'can',
#    'tell',
#    'the',
#    'veggies',
#    'are',
#    'fresh',
#    'just',
#    'by',
#    'looking',
#    'at',
#    'them',
#    '.',
#    'the',
#    'gyro',
#    'was',
#    'one',
#    'of',
#    'the',
#    'best',
#    'i',
#    "'ve",
#    'had',
#    'and',
#    'the',
#    'fries',
#    'were',
#    'awesome',
#    '.',
#    'great',
#    'service',
#    '!',
#    'they',
#    'really',
#    'care',
#    'about',
#    'giving',
#    'you',
#    'a',
#    'good',
#    'experience',
#    '.',
#    'i',
#    'will',
#    'definitely',
#    'be',
#    'back',
#    '!'],
#   ['you',
#    'have',
#    'to',
#    'go',
#    'to',
#    'this',
#    'place',
#    'to',
#    'try',
#    'chinese',
#    '-',
#    'fusion',
#    'cuisine',
#    '.',
#    'we',
#    'have',
#    'a',
#    'very',
#    'sweet',
#    'server',
#    'who',
#    'helped',
#    'us',
#    'in',
#    'selecting',
#    'a',
#    'few',
#    'items',
#    'as',
#    'per',
#    'our',
#    'preference',
#    'and',
#    'spice',
#    'tolerance',
#    '.',
#    'all',
#    'the',
#    'servers',
#    'are',
#    'very',
#    'sweet',
#    'and',
#    'friendly',
#    '.',
#    'try',
#    'the',
#    'sweet',
#    'corn',
#    'soup',
#    ',',
#    'chicken',
#    'manchurian',
#    'if',
#    'is',
#    'very',
#    'soft',
#    'and',
#    'not',
#    'too',
#    'spicy',
#    '.',
#    'american',
#    'chopsuey',
#    'is',
#    'also',
#    'one',
#    'of',
#    'our',
#    'favorites',
#    '.',
#    'thank',
#    'you',
#    'inchin',
#    'bamboo',
#    'garden',
#    'for',
#    'great',
#    'service',
#    'and',
#    'food',
#    ')'],
#   ['what',
#    'a',
#    'great',
#    'place',
#    '!',
#    'love',
#    'the',
#    'food',
#    'and',
#    'the',
#    'atmosphere',
#    '!',
#    'i',
#    'was',
#    'in',
#    'last',
#    'friday',
#    'and',
#    'although',
#    'it',
#    'was',
#    'packed',
#    'due',
#    'to',
#    'phoenix',
#    'comicon',
#    ',',
#    'a',
#    'dbacks',
#    'game',
#    ',',
#    'the',
#    'phoeinix',
#    'symphony',
#    'and',
#    'first',
#    'friday',
#    '...',
#    'we',
#    'got',
#    'a',
#    'table',
#    'in',
#    'the',
#    'bar',
#    ',',
#    'had',
#    'attentive',
#    'service',
#    'and',
#    'made',
#    'it',
#    'out',
#    'just',
#    'in',
#    'time',
#    'to',
#    'make',
#    'it',
#    'to',
#    'the',
#    'phoenix',
#    'symphony',
#    'for',
#    'our',
#    'show',
#    '!',
#    'my',
#    'boyfriend',
#    'and',
#    'i',
#    'went',
#    'in',
#    'yesterday',
#    'to',
#    'enjoy',
#    'some',
#    'drinks',
#    'and',
#    'appetizers',
#    'for',
#    'the',
#    'afternoon',
#    'and',
#    'had',
#    'a',
#    'wonderful',
#    'time',
#    'again',
#    '!',
#    'lauren',
#    'was',
#    'our',
#    'server',
#    'and',
#    'she',
#    'was',
#    'fabulous',
#    '!',
#    'again',
#    'attentive',
#    'and',
#    'made',
#    'sure',
#    'we',
#    'had',
#    'everything',
#    'we',
#    'needed',
#    '!',
#    'i',
#    'will',
#    'definitely',
#    'be',
#    'back',
#    '!'],
#   ['i',
#    'am',
#    'not',
#    'surprised',
#    'to',
#    'see',
#    'all',
#    'the',
#    '5',
#    'star',
#    'reviews',
#    '.',
#    'victor',
#    'guerrero',
#    'has',
#    'got',
#    'window',
#    'tinting',
#    'down',
#    'pat',
#    '.',
#    'very',
#    'fair',
#    'prices',
#    'considering',
#    'the',
#    'quality',
#    'of',
#    'tint',
#    'he',
#    'uses',
#    '.',
#    'he',
#    "'s",
#    'done',
#    '4',
#    'cars',
#    'of',
#    'mine',
#    'in',
#    'the',
#    'past',
#    'and',
#    'i',
#    'never',
#    'had',
#    'a',
#    'single',
#    'issue',
#    'with',
#    'any',
#    'of',
#    'them',
#    '.',
#    'definately',
#    'recommend',
#    '!'],
#   ['this',
#    'was',
#    'one',
#    'of',
#    'those',
#    'hipster',
#    'trendy',
#    'places',
#    'that',
#    'make',
#    'pho',
#    'cool',
#    '.',
#    'or',
#    'shall',
#    'i',
#    'say',
#    'hot',
#    '?',
#    ';)',
#    'ok',
#    'bad',
#    'joke',
#    '.',
#    'but',
#    'i',
#    'ordered',
#    '"',
#    'the',
#    'american',
#    '"',
#    ',',
#    'super',
#    'good-',
#    'it',
#    "'s",
#    'basically',
#    'beef',
#    'pho',
#    '.',
#    'it',
#    'was',
#    '$',
#    '10',
#    'though',
#    ',',
#    'which',
#    'is',
#    'fine',
#    'but',
#    'i',
#    "'m",
#    'used',
#    'to',
#    'paying',
#    'cheaper',
#    'than',
#    '6',
#    'dollars',
#    'for',
#    'pho',
#    '.',
#    'also',
#    ',',
#    'i',
#    'feel',
#    'like',
#    'pho',
#    'is',
#    'known',
#    'for',
#    'how',
#    'cheap',
#    'it',
#    'is',
#    'and',
#    'how',
#    'big',
#    'portions',
#    'you',
#    'get',
#    '.',
#    'the',
#    'food',
#    'was',
#    'really',
#    'tasty',
#    '.',
#    'there',
#    'is',
#    'a',
#    'little',
#    'self',
#    'serve',
#    'pho',
#    'bar',
#    ',',
#    'where',
#    'you',
#    'get',
#    'your',
#    'sides',
#    'like',
#    'sauce',
#    ',',
#    'limes',
#    ',',
#    'bamboo',
#    ',',
#    'greens',
#    ',',
#    'etc',
#    '.',
#    'i',
#    'like',
#    'how',
#    'the',
#    'restaurant',
#    'has',
#    'their',
#    'own',
#    'variety',
#    'of',
#    'sauces',
#    'to',
#    'add',
#    'to',
#    'your',
#    'pho',
#    '.',
#    'i',
#    'did',
#    'also',
#    'notice',
#    'that',
#    'the',
#    'soup',
#    'did',
#    "n't",
#    'come',
#    'with',
#    'that',
#    'much',
#    'noodles',
#    '.',
#    'there',
#    'was',
#    'a',
#    'lot',
#    'of',
#    'beef',
#    'though',
#    '!',
#    'which',
#    'is',
#    'a',
#    'plus',
#    '.',
#    'the',
#    'proportions',
#    'did',
#    "n't",
#    'really',
#    'even',
#    'out',
#    '.',
#    '4',
#    'stars',
#    'for',
#    'the',
#    'food',
#    'and',
#    'friendly',
#    'customer',
#    'service',
#    '.',
#    'minus',
#    'one',
#    'star',
#    'because',
#    'of',
#    'the',
#    'price',
#    '.',
#    'i',
#    'think',
#    'all',
#    'genuine',
#    'pho',
#    'lovers',
#    'can',
#    'agree',
#    'with',
#    'me',
#    'though',
#    ',',
#    'pho',
#    'is',
#    'usually',
#    'cheap',
#    '!'],
#   ['every',
#    'time',
#    'i',
#    'go',
#    'here',
#    'and',
#    'order',
#    'milk',
#    'tea',
#    'it',
#    'just',
#    'gets',
#    'better',
#    'and',
#    'better',
#    ',',
#    'staff',
#    'is',
#    'very',
#    'nice',
#    'too',
#    '!',
#    'i',
#    'have',
#    'my',
#    'regular',
#    'server',
#    ',',
#    'name',
#    'is',
#    'puck',
#    'i',
#    'believe',
#    ',',
#    'very',
#    'accommodating',
#    '.'],
#   ['wow',
#    '!',
#    'this',
#    'was',
#    'the',
#    'best',
#    'pedicure',
#    'that',
#    'i',
#    'have',
#    'had',
#    'in',
#    'a',
#    'long',
#    'time',
#    '.',
#    'i',
#    'had',
#    'one',
#    'not',
#    'too',
#    'long',
#    'ago',
#    'at',
#    'oasis',
#    'day',
#    'spa',
#    'for',
#    '$',
#    '60',
#    'and',
#    'it',
#    'did',
#    "n't",
#    'even',
#    'compare',
#    '.',
#    'they',
#    'recently',
#    'got',
#    'new',
#    'massage',
#    'pedicure',
#    'chairs',
#    'that',
#    'are',
#    'amazing',
#    '!',
#    'for',
#    'only',
#    '$',
#    '30.00',
#    'it',
#    'was',
#    'really',
#    'great',
#    'service',
#    '.',
#    'they',
#    'really',
#    'take',
#    'their',
#    'time',
#    'and',
#    'give',
#    'you',
#    'an',
#    'amazing',
#    'foot',
#    'and',
#    'leg',
#    'massage',
#    'and',
#    'the',
#    'people',
#    'are',
#    'extremely',
#    'friendly',
#    '.',
#    'they',
#    'even',
#    'offered',
#    'us',
#    'each',
#    'a',
#    'bottle',
#    'of',
#    'water',
#    'when',
#    'we',
#    'walked',
#    'in',
#    '.',
#    'i',
#    'will',
#    'definitely',
#    'be',
#    'back',
#    'and',
#    'i',
#    'sent',
#    'my',
#    'mom',
#    'there',
#    'and',
#    'she',
#    'loved',
#    'it',
#    'too',
#    '!',
#    'no',
#    'more',
#    'groupon',
#    'pedicures',
#    'for',
#    'me',
#    '!'],
#   ['love',
#    'the',
#    'chile',
#    'relleno',
#    ',',
#    'get',
#    'it',
#    'with',
#    'the',
#    'ranchero',
#    'sauce',
#    'on',
#    'the',
#    'side',
#    'so',
#    'you',
#    'can',
#    'enjoy',
#    'the',
#    'crispy',
#    'relleno',
#    'and',
#    'still',
#    'get',
#    'the',
#    'tasty',
#    'ranchero',
#    'sauce',
#    '.',
#    'the',
#    'nachos',
#    'serving',
#    'was',
#    'so',
#    'huge',
#    ',',
#    'my',
#    'kids',
#    'shared',
#    'it',
#    'and',
#    'still',
#    'brought',
#    'some',
#    'home',
#    '.',
#    'super',
#    'friendly',
#    'service',
#    '.'],
#   ['i',
#    'love',
#    'what',
#    'bonnie',
#    'brooks',
#    'the',
#    'former',
#    'ceo',
#    'has',
#    'done',
#    'to',
#    'revive',
#    'the',
#    'hudson',
#    'bay',
#    'stores',
#    '.',
#    'i',
#    'had',
#    'the',
#    'pleasure',
#    'of',
#    'shopping',
#    'at',
#    'lane',
#    'crawford',
#    'in',
#    'hong',
#    'kong',
#    ',',
#    'another',
#    'place',
#    'bonnie',
#    'has',
#    'left',
#    'her',
#    'fingerprint',
#    '.',
#    'the',
#    'hudson',
#    'bay',
#    'was',
#    'my',
#    'go',
#    'to',
#    'store',
#    '15',
#    '+',
#    'years',
#    'ago',
#    'and',
#    'i',
#    'stopped',
#    'shopping',
#    'their',
#    'about',
#    '10',
#    'years',
#    'ago',
#    'as',
#    'they',
#    'began',
#    'to',
#    'diversify',
#    'too',
#    'much',
#    'and',
#    'became',
#    'and',
#    'expert',
#    'at',
#    'nothing',
#    'including',
#    'fashion',
#    '.',
#    'bonnie',
#    ',',
#    'the',
#    'former',
#    'ceo',
#    'of',
#    'hudson',
#    'bay',
#    'has',
#    'started',
#    'a',
#    'transition',
#    'back',
#    'to',
#    'its',
#    'roots',
#    'and',
#    'bringing',
#    'in',
#    'a',
#    'lot',
#    'of',
#    'high',
#    'end',
#    'exclusive',
#    'lines',
#    'and',
#    'departments',
#    'including',
#    'reviving',
#    'the',
#    'room',
#    'at',
#    'its',
#    'flagship',
#    'location',
#    'and',
#    'as',
#    'a',
#    'result',
#    ',',
#    'gone',
#    'is',
#    'the',
#    'tv',
#    'department',
#    'and',
#    'other',
#    'high',
#    'maintenance',
#    'low',
#    'profit',
#    'lines',
#    '.',
#    'i',
#    'do',
#    'find',
#    'myself',
#    'suddenly',
#    'dropping',
#    'in',
#    'to',
#    'see',
#    'what',
#    'is',
#    'new',
#    'and',
#    'always',
#    'seem',
#    'to',
#    'walk',
#    'out',
#    'with',
#    'a',
#    'purchase',
#    '.',
#    'good',
#    'show',
#    'bonnie',
#    ',',
#    'nice',
#    'to',
#    'have',
#    'you',
#    'back',
#    'in',
#    'toronto',
#    '.',
#    'i',
#    'hope',
#    'the',
#    'new',
#    'ceo',
#    'has',
#    'the',
#    'same',
#    'clear',
#    'vision',
#    'bonnie',
#    'had',
#    'while',
#    'at',
#    'the',
#    'wheel',
#    '.'],
#   ['we',
#    'have',
#    'only',
#    'been',
#    'through',
#    'the',
#    'drive',
#    'thru',
#    'so',
#    'i',
#    'have',
#    'no',
#    'idea',
#    'what',
#    'it',
#    'is',
#    'like',
#    'inside',
#    '...',
#    'but',
#    'their',
#    'food',
#    'is',
#    'bomb',
#    '.',
#    'such',
#    'a',
#    'great',
#    'bean',
#    'burro',
#    '!',
#    'they',
#    'are',
#    'also',
#    'always',
#    'very',
#    'nice',
#    ':)'],
#   ['has',
#    'a',
#    'california',
#    'beachfront',
#    'feel',
#    'to',
#    'the',
#    'restaurant',
#    '.',
#    'from',
#    'swimming',
#    'trunks',
#    'and',
#    'bikini',
#    "'s",
#    'hang',
#    'from',
#    'ceiling',
#    ',',
#    'to',
#    'the',
#    'surfboards',
#    'hanging',
#    'on',
#    'the',
#    'walls',
#    '.',
#    'very',
#    'friendly',
#    'staff',
#    'and',
#    'the',
#    'food',
#    'is',
#    'good',
#    ',',
#    'a',
#    'bit',
#    'pricey',
#    'but',
#    'good',
#    '.'],
#   ['while',
#    'visiting',
#    'during',
#    'a',
#    'conference',
#    'we',
#    'first',
#    'ate',
#    'here',
#    'for',
#    'lunch',
#    '.',
#    'service',
#    'was',
#    'outstanding',
#    'and',
#    'the',
#    'food',
#    'was',
#    'nothing',
#    'short',
#    'of',
#    'delicious',
#    '.',
#    'i',
#    'had',
#    'the',
#    'swine',
#    'burger',
#    '2.0',
#    'that',
#    'hit',
#    'the',
#    'spot',
#    '!',
#    'on',
#    'a',
#    'different',
#    'night',
#    'i',
#    'had',
#    'the',
#    'pork',
#    'ribs',
#    'that',
#    'had',
#    'a',
#    'phenomenal',
#    'flavor',
#    'with',
#    'a',
#    'bit',
#    'of',
#    'spice',
#    '.',
#    'everything',
#    'was',
#    'great',
#    'and',
#    'again',
#    'the',
#    'service',
#    'was',
#    'outstanding',
#    '...',
#    'highly',
#    'recommend',
#    '.'],
#   ['the',
#    'cost',
#    'model',
#    'is',
#    'very',
#    'good',
#    '.',
#    'middling',
#    'quality',
#    'sushi',
#    'but',
#    'no',
#    'plate',
#    'is',
#    'priced',
#    'over',
#    '$',
#    '2',
#    '.',
#    'so',
#    'honestly',
#    ',',
#    'for',
#    'my',
#    'budget',
#    ',',
#    'i',
#    "'d",
#    'eat',
#    'here',
#    'more',
#    'often',
#    'b',
#    '/',
#    'c',
#    'it',
#    'is',
#    'good',
#    'for',
#    'a',
#    'quick',
#    'cheap',
#    'sushi',
#    'fix',
#    'than',
#    'if',
#    'it',
#    'was',
#    'pricey',
#    'for',
#    'good',
#    'quality',
#    'sushi',
#    '.',
#    'the',
#    'only',
#    'standouts',
#    '--',
#    'eel',
#    'and',
#    'this',
#    'other',
#    'plate',
#    'of',
#    'krab',
#    'w/',
#    'tuna',
#    'slice',
#    'wrapped',
#    'around',
#    'it',
#    'w/',
#    'avacado',
#    'on',
#    'it',
#    '.',
#    'i',
#    'would',
#    "n't",
#    'take',
#    'a',
#    'die',
#    'hard',
#    'sushi',
#    'fan',
#    'here',
#    ',',
#    'but',
#    'i',
#    'would',
#    'take',
#    'someone',
#    'who',
#    'does',
#    "n't",
#    'eat',
#    'sushi',
#    'much',
#    'so',
#    'would',
#    "n't",
#    'care',
#    'anyhow',
#    'and',
#    'would',
#    'enjoy',
#    'the',
#    'conveyer',
#    'belt',
#    'concept',
#    '.'],
#   ['they',
#    'odds',
#    'of',
#    'winning',
#    'are',
#    'bad',
#    '!',
#    'you',
#    'are',
#    'more',
#    'likely',
#    'to',
#    'get',
#    'slap',
#    'with',
#    'a',
#    'frog',
#    'than',
#    'wining',
#    'something',
#    'above',
#    '50',
#    'cents',
#    '!',
#    'my',
#    'friends',
#    'and',
#    'i',
#    'each',
#    'spend',
#    'money',
#    'and',
#    'we',
#    'did',
#    "n't",
#    'even',
#    'got',
#    'teased',
#    '!'],
#   ['i',
#    'went',
#    'for',
#    'color',
#    'and',
#    'jennifer',
#    'was',
#    'amazing',
#    '.',
#    'she',
#    'was',
#    'super',
#    'sweet',
#    'and',
#    'made',
#    'sure',
#    'my',
#    'hair',
#    'was',
#    'exactly',
#    'how',
#    'i',
#    'wanted',
#    'it',
#    '...',
#    'even',
#    'though',
#    'i',
#    "'m",
#    'picky',
#    'and',
#    'she',
#    'had',
#    'to',
#    'redo',
#    'a',
#    'section',
#    '.',
#    'i',
#    'will',
#    'for',
#    'sure',
#    'be',
#    'returning',
#    'to',
#    'see',
#    'her',
#    '.'],
#   ['angel',
#    'and',
#    'his',
#    'crew',
#    'did',
#    'an',
#    'amazing',
#    'job',
#    'on',
#    'our',
#    'outdoor',
#    'kitchen',
#    'project',
#    '!',
#    '!',
#    'they',
#    'were',
#    'patient',
#    'when',
#    'the',
#    'general',
#    'contractor',
#    'was',
#    'behind',
#    'schedule',
#    'and',
#    'stayed',
#    'in',
#    'contact',
#    'with',
#    'us',
#    'until',
#    'the',
#    'time',
#    'was',
#    'right',
#    '.',
#    'installation',
#    'was',
#    'perfect',
#    'and',
#    'they',
#    'nailed',
#    'the',
#    'waterfall',
#    'edge',
#    '.',
#    'many',
#    'people',
#    'can',
#    'not',
#    'believe',
#    'there',
#    'is',
#    'a',
#    'seam',
#    ',',
#    'its',
#    'flawless',
#    '!',
#    'we',
#    "'ll",
#    'definitely',
#    'use',
#    'them',
#    'again',
#    'and',
#    'tell',
#    'our',
#    'friends',
#    'and',
#    'family',
#    'about',
#    'vegas',
#    'granite',
#    '!'],
#   ['we',
#    'took',
#    'a',
#    'risk',
#    'and',
#    'picked',
#    'a',
#    'mexican',
#    'place',
#    'not',
#    'close',
#    'to',
#    'us',
#    'based',
#    'on',
#    'the',
#    'ratings',
#    'on',
#    'yelp',
#    '.',
#    'we',
#    'read',
#    'that',
#    'the',
#    'portions',
#    'were',
#    'good',
#    'and',
#    'the',
#    'flavor',
#    'was',
#    'too',
#    '.',
#    'we',
#    'were',
#    'not',
#    'disappointed',
#    '.',
#    'i',
#    'had',
#    'the',
#    'flag',
#    'enchiladas',
#    ',',
#    'a',
#    'great',
#    'mix',
#    'of',
#    'flavors',
#    ',',
#    'it',
#    'was',
#    'very',
#    'good',
#    '!',
#    'we',
#    'also',
#    'had',
#    'chips',
#    'and',
#    'salsa',
#    ',',
#    'not',
#    'my',
#    'favorite',
#    'but',
#    'decent',
#    '.',
#    'i',
#    'would',
#    'definitely',
#    'return',
#    '.'],
#   ['called',
#    'them',
#    'to',
#    'spray',
#    'off',
#    'the',
#    'leaves',
#    'and',
#    'bird',
#    'droppings',
#    'from',
#    'my',
#    'roof',
#    '.',
#    'great',
#    'job',
#    '.',
#    'same',
#    'day',
#    'quote',
#    '.',
#    'next',
#    'day',
#    'service',
#    '.',
#    'affordable',
#    'and',
#    'friendly',
#    '.'],
#   ['restaurant',
#    'was',
#    '3',
#    'quarters',
#    'full',
#    'and',
#    'we',
#    'were',
#    'seated',
#    'immediately',
#    '.',
#    'the',
#    'food',
#    'was',
#    'delicious',
#    'but',
#    'we',
#    'had',
#    'to',
#    'continuously',
#    'ask',
#    'for',
#    'items',
#    'and',
#    'we',
#    'were',
#    'missing',
#    'a',
#    'dish',
#    '.',
#    'seemed',
#    'like',
#    'they',
#    'were',
#    'low',
#    'on',
#    'staff',
#    '.',
#    'the',
#    'food',
#    'was',
#    'good',
#    'but',
#    'the',
#    'service',
#    'was',
#    "n't",
#    'too',
#    'great',
#    '.'],
#   ['let',
#    'me',
#    'start',
#    'off',
#    'by',
#    'saying',
#    'service',
#    'was',
#    'beyond',
#    'awesome',
#    'here',
#    '.',
#    'the',
#    'first',
#    'dish',
#    'i',
#    'ordered',
#    ',',
#    'i',
#    'did',
#    'not',
#    'realize',
#    'was',
#    'finished',
#    'in',
#    'the',
#    'pan',
#    ',',
#    'and',
#    'fried',
#    '.',
#    'i',
#    'hate',
#    'friend',
#    ',',
#    'or',
#    'pan',
#    'friend',
#    'fish',
#    'period',
#    '.',
#    'i',
#    'told',
#    'the',
#    'waiter',
#    'what',
#    'i',
#    'wanted',
#    '.',
#    'the',
#    'only',
#    'fish',
#    'they',
#    'had',
#    'not',
#    'friend',
#    'or',
#    'finished',
#    'in',
#    'the',
#    'pan',
#    'was',
#    'the',
#    'halibut',
#    '.',
#    'so',
#    'the',
#    'chef',
#    'made',
#    'a',
#    'special',
#    'halibut',
#    'dish',
#    'for',
#    'me',
#    'int',
#    'he',
#    'over',
#    'that',
#    'was',
#    'seriously',
#    ',',
#    'to',
#    'die',
#    'for',
#    '!'],
#   ['excellent',
#    'food',
#    ',',
#    'great',
#    'atmosphere',
#    ',',
#    'wonderful',
#    'service',
#    '!',
#    'i',
#    'grabbed',
#    'dinner',
#    'here',
#    'with',
#    'some',
#    'colleagues',
#    'after',
#    'a',
#    'conference',
#    ',',
#    'and',
#    'we',
#    'greatly',
#    'enjoyed',
#    'our',
#    'meal',
#    '.',
#    'howie',
#    'was',
#    'a',
#    'great',
#    'server',
#    ',',
#    'and',
#    'was',
#    'able',
#    'to',
#    'recommend',
#    'some',
#    'of',
#    'his',
#    'favorite',
#    'things',
#    'on',
#    'the',
#    'menu',
#    'to',
#    'our',
#    'indecisive',
#    'group',
#    '.',
#    'make',
#    'sure',
#    'to',
#    'save',
#    'room',
#    'for',
#    'the',
#    'peach',
#    'cobbler',
#    '!'],
#   ['i',
#    "'ve",
#    'been',
#    'searching',
#    'for',
#    'a',
#    'great',
#    'deal',
#    'on',
#    'a',
#    'leather',
#    'sectional',
#    'and',
#    'this',
#    'couch',
#    'is',
#    'exactly',
#    'what',
#    'i',
#    "'m",
#    'looking',
#    'for',
#    '!',
#    'ken',
#    'was',
#    'very',
#    'helpful',
#    'and',
#    'patient',
#    'listening',
#    'to',
#    'my',
#    'needs',
#    'and',
#    'what',
#    'would',
#    'work',
#    '.',
#    'he',
#    'is',
#    'easy',
#    'to',
#    'talk',
#    'to',
#    'and',
#    'knowledgeable',
#    'about',
#    'the',
#    'furniture',
#    '.',
#    'they',
#    'have',
#    'an',
#    'array',
#    'of',
#    'different',
#    'styles',
#    'and',
#    'he',
#    'can',
#    'order',
#    'them',
#    'promptly',
#    'and',
#    'pricing',
#    'is',
#    'affordable',
#    '.',
#    'i',
#    'am',
#    'very',
#    'happy',
#    'i',
#    'found',
#    'them',
#    '.',
#    'thank',
#    'you',
#    ',',
#    'ken',
#    '.'],
#   ['this',
#    'place',
#    'does',
#    'it',
#    'for',
#    'me',
#    '.',
#    '$',
#    '1.50',
#    'a',
#    'ticket',
#    'is',
#    'cool',
#    'they',
#    'always',
#    'have',
#    'family',
#    'shows',
#    'playing',
#    ',',
#    'my',
#    'kidz',
#    'love',
#    'it',
#    '.',
#    'six',
#    'of',
#    'us',
#    'for',
#    '9',
#    'bucks',
#    'you',
#    'ca',
#    'nt',
#    'beat',
#    'it',
#    '.',
#    'the',
#    'popcorn',
#    'is',
#    '$',
#    '5.25',
#    'for',
#    'a',
#    'large',
#    'with',
#    '1',
#    'refill',
#    'then',
#    'they',
#    'have',
#    'the',
#    'popcorn',
#    'seasoning',
#    'white',
#    'cheddar',
#    ',',
#    'ranch',
#    ',',
#    'jalapeno',
#    'cheddar',
#    ',',
#    'nacho',
#    'cheese',
#    '.',
#    'no',
#    'other',
#    'cinema',
#    'i',
#    "'ve",
#    'been',
#    'too',
#    'have',
#    'the',
#    'seasonings',
#    'soo',
#    '.',
#    '5',
#    'stars',
#    'from',
#    'me'],
#   ['very',
#    'good',
#    'food',
#    '.',
#    'however',
#    ',',
#    'bad',
#    'service',
#    '.',
#    'we',
#    'went',
#    'there',
#    'and',
#    'it',
#    'took',
#    'the',
#    'server',
#    'more',
#    'than',
#    '20',
#    'minutes',
#    'to',
#    'bring',
#    'the',
#    'men',
#    ',',
#    'we',
#    'actually',
#    'had',
#    'to',
#    'tell',
#    'him',
#    '"',
#    'hello',
#    'were',
#    'here',
#    '"',
#    '.',
#    'it',
#    'feels',
#    'like',
#    'the',
#    'staff',
#    'over',
#    'here',
#    'are',
#    'not',
#    'happy',
#    'with',
#    'their',
#    'work',
#    ',',
#    'and',
#    'they',
#    'try',
#    'to',
#    'get',
#    'this',
#    'out',
#    'on',
#    'customers',
#    '.'],
#   ['as',
#    'usual',
#    'this',
#    'buffet',
#    'does',
#    "n't",
#    'disappoint',
#    '.',
#    'the',
#    'gelato',
#    'is',
#    'awesome',
#    'as',
#    'well',
#    'as',
#    'the',
#    'cookies',
#    'we',
#    'had',
#    '.',
#    'the',
#    'food',
#    'is',
#    'really',
#    'good',
#    ',',
#    'except',
#    'for',
#    'a',
#    'few',
#    'things',
#    'we',
#    'had',
#    'were',
#    'ok',
#    '.',
#    'we',
#    'had',
#    'the',
#    'lunch',
#    'buffet',
#    'here',
#    '.',
#    'overall',
#    'is',
#    'was',
#    'a',
#    'very',
#    'good',
#    'experience',
#    '.'],
#   ['it',
#    "'s",
#    'like',
#    'a',
#    'panda',
#    'express',
#    'meets',
#    'any',
#    'of',
#    'the',
#    'taquerias',
#    'you',
#    'see',
#    'around',
#    'the',
#    'valley',
#    '.',
#    'the',
#    'jerk',
#    'chicken',
#    'is',
#    'my',
#    'personal',
#    'favorite',
#    'for',
#    'the',
#    'quesadillas',
#    'and',
#    'the',
#    'black',
#    'beans',
#    'are',
#    'a-1',
#    ',',
#    'would',
#    'slap',
#    'someone',
#    "'s",
#    'momma',
#    ',',
#    'just',
#    'not',
#    'mines',
#    '.',
#    'this',
#    'establishment',
#    'has',
#    'been',
#    'around',
#    'for',
#    'years',
#    'and',
#    'the',
#    'food',
#    'is',
#    'consistently',
#    'good',
#    '.'],
#   ['good',
#    'hookah',
#    'lounge',
#    '.',
#    'friendly',
#    'staff',
#    ',',
#    'wide',
#    'selection',
#    'of',
#    'hookah',
#    'flavours',
#    '.',
#    'nice',
#    'place',
#    'to',
#    'chillout',
#    '.'],
#   ['my',
#    'son',
#    'likes',
#    'to',
#    'go',
#    'because',
#    'of',
#    'the',
#    'cool',
#    'stuff',
#    '!',
#    'they',
#    'need',
#    'new',
#    'chairs',
#    'the',
#    'plastic',
#    'lawn',
#    'chairs',
#    'are',
#    'not',
#    'comfortable',
#    'if',
#    'you',
#    'have',
#    'to',
#    'sit',
#    'more',
#    'than',
#    '10',
#    'minutes',
#    '!',
#    'food',
#    'is',
#    'hit',
#    'or',
#    'miss',
#    'but',
#    'staff',
#    'is',
#    'usually',
#    'very',
#    'nice',
#    '.'],
#   ['the',
#    'observation',
#    'deck',
#    'is',
#    'great',
#    '.',
#    'my',
#    'young',
#    'children',
#    'were',
#    "n't",
#    'very',
#    'interested',
#    'but',
#    'that',
#    'could',
#    'be',
#    'because',
#    'they',
#    "'ve",
#    'been',
#    'ruined',
#    'by',
#    'the',
#    'willis',
#    'tower',
#    '.',
#    'but',
#    ',',
#    'i',
#    'love',
#    'cleveland',
#    '.',
#    'it',
#    "'s",
#    'beautiful',
#    '!',
#    'so',
#    ',',
#    'i',
#    'enjoyed',
#    'the',
#    'deck',
#    '.',
#    'the',
#    'food',
#    'court',
#    'is',
#    'nice',
#    ',',
#    'very',
#    'crowded',
#    '.',
#    'hard',
#    'rick',
#    'is',
#    'a',
#    'plus',
#    'at',
#    'this',
#    'mall',
#    '.',
#    'shopping',
#    'is',
#    'pretty',
#    'limited',
#    '.'],
#   ['definitely',
#    'worth',
#    'parking',
#    'here',
#    ',',
#    'especially',
#    'if',
#    'you',
#    "'re",
#    'traveling',
#    'over',
#    'any',
#    'period',
#    'of',
#    'time',
#    'in',
#    'cleveland',
#    'that',
#    'involves',
#    'snow',
#    'fall',
#    '(',
#    'november',
#    'to',
#    'like',
#    'april',
#    ')',
#    '.',
#    'get',
#    'in',
#    'on',
#    'their',
#    'member',
#    'rewards',
#    ',',
#    'and',
#    'they',
#    "'ll",
#    'send',
#    'you',
#    'a',
#    'card',
#    'that',
#    'you',
#    'can',
#    'insert',
#    'and',
#    'use',
#    'instead',
#    'of',
#    'taking',
#    'a',
#    'ticket',
#    'every',
#    'time',
#    'you',
#    'park',
#    '.',
#    'you',
#    'can',
#    'build',
#    'up',
#    'free',
#    'parking',
#    'with',
#    'your',
#    'stays',
#    '.',
#    'if',
#    'you',
#    'work',
#    'for',
#    'uh',
#    ',',
#    'sign',
#    'up',
#    'through',
#    'uh',
#    "'s",
#    'group',
#    'rates',
#    'and',
#    'it',
#    'saves',
#    'you',
#    'a',
#    'little',
#    'bit',
#    'of',
#    'money',
#    'to',
#    'boot',
#    '(',
#    'especially',
#    'if',
#    'you',
#    'stay',
#    'for',
#    'an',
#    'extended',
#    'period',
#    'of',
#    'time',
#    ')',
#    '.',
#    'perk',
#    'is',
#    'that',
#    'they',
#    'have',
#    'complimentary',
#    'water',
#    'as',
#    'your',
#    'leaving',
#    'and',
#    'i',
#    'wo',
#    "n't",
#    'have',
#    'to',
#    'worry',
#    'about',
#    'scrapping',
#    'my',
#    'car',
#    'when',
#    'i',
#    'come',
#    'back',
#    'from',
#    'a',
#    'winter',
#    'trip'],
#   ['luv',
#    'this',
#    'place',
#    ',',
#    'it',
#    'does',
#    "n't",
#    'look',
#    'like',
#    'much',
#    'from',
#    'outside',
#    'but',
#    'when',
#    'you',
#    'get',
#    'inside',
#    'the',
#    'atmosphere',
#    'is',
#    'entirely',
#    'different',
#    '.',
#    'it',
#    "'s",
#    'real',
#    'chill',
#    'and',
#    'everything',
#    'is',
#    'great',
#    'music',
#    ',',
#    'food',
#    ',',
#    'drinks',
#    'etc',
#    '.',
#    'i',
#    'absolutely',
#    'have',
#    'nothing',
#    'bad',
#    'to',
#    'say',
#    'about',
#    'this',
#    'place',
#    '.'],
#   ['use',
#    'caution',
#    'with',
#    'this',
#    'location----they',
#    'sold',
#    'me',
#    'a',
#    'clearly',
#    'used',
#    'product',
#    'as',
#    'new',
#    '--',
#    'i',
#    'did',
#    "n't",
#    'detect',
#    'this',
#    'until',
#    'i',
#    'got',
#    'home',
#    '---',
#    'they',
#    'agreed',
#    'to',
#    'replace',
#    '---',
#    'however',
#    'in',
#    'my',
#    'opinion',
#    'this',
#    'is',
#    'a',
#    'deceptive',
#    'and',
#    'innapropriate',
#    'business',
#    'practice',
#    '.',
#    'i',
#    'usually',
#    'shop',
#    'at',
#    'the',
#    'tatum',
#    'store',
#    '--',
#    'where',
#    'i',
#    'have',
#    'never',
#    'had',
#    'a',
#    'problem',
#    'before',
#    '---',
#    'so',
#    'for',
#    'me',
#    'i',
#    'am',
#    'only',
#    'going',
#    'to',
#    'tatum',
#    'from',
#    'now',
#    'on',
#    '.'],
#   ['wow',
#    '!',
#    'was',
#    'here',
#    'for',
#    'the',
#    'opening',
#    'concert',
#    '(',
#    'the',
#    'killers',
#    'with',
#    'wayne',
#    'newton',
#    ',',
#    'blue',
#    'men',
#    'group',
#    ',',
#    'showgirls',
#    ',',
#    'etc',
#    '.',
#    ')',
#    '.',
#    'there',
#    'were',
#    'performers',
#    'outside',
#    'the',
#    'arena',
#    'who',
#    'were',
#    'great',
#    '.',
#    'fast',
#    ',',
#    'easy',
#    'entrance',
#    'even',
#    'with',
#    'security',
#    'and',
#    'a',
#    'huge',
#    'crowd',
#    '.',
#    'entertainers',
#    'inside',
#    'before',
#    'the',
#    'concert',
#    '.',
#    'nice',
#    'bathrooms',
#    '.',
#    'good',
#    'merchandise',
#    'and',
#    'food',
#    '/',
#    'drink',
#    'sales',
#    'areas',
#    '.',
#    'the',
#    'seats',
#    'were',
#    'okay',
#    '.',
#    'decent',
#    'sight',
#    'lines',
#    'to',
#    'the',
#    'stage',
#    'with',
#    'two',
#    'large',
#    'screens',
#    '.',
#    'there',
#    'were',
#    'fireworks',
#    'outside',
#    'after',
#    'the',
#    'concert',
#    '.',
#    'fun',
#    'night',
#    '!',
#    'we',
#    'stayed',
#    'at',
#    'the',
#    'aria',
#    'so',
#    'we',
#    'could',
#    'walk',
#    'to',
#    'the',
#    'arena',
#    'since',
#    'parking',
#    'would',
#    'be',
#    'expensive',
#    'and',
#    'a',
#    'pain',
#    '.'],
#   ['hot',
#    'yoga',
#    'markham',
#    'still',
#    'one',
#    'of',
#    'my',
#    'favourite',
#    'studio',
#    '.',
#    'used',
#    'the',
#    'passport',
#    'to',
#    'prana',
#    'for',
#    'a',
#    'visit',
#    'in',
#    'one',
#    'of',
#    'the',
#    'hot',
#    'yoga',
#    'classes',
#    '.',
#    'nash',
#    'was',
#    'the',
#    'teacher',
#    'and',
#    'he',
#    'was',
#    'funny',
#    'and',
#    'lighthearted',
#    'and',
#    'everyone',
#    'seems',
#    'to',
#    'enjoyed',
#    'the',
#    'class',
#    '.',
#    'there',
#    'were',
#    'quite',
#    'a',
#    'few',
#    'first',
#    'timer',
#    'so',
#    'the',
#    'class',
#    'was',
#    'more',
#    'like',
#    'a',
#    'beginner',
#    'level',
#    '.',
#    'nash',
#    'was',
#    'really',
#    'helpful',
#    'going',
#    'all',
#    'around',
#    'and',
#    'helping',
#    'us',
#    'all',
#    'with',
#    'the',
#    'poses',
#    '.',
#    'ca',
#    "n't",
#    'wait',
#    'to',
#    'go',
#    'back',
#    'again',
#    'for',
#    'another',
#    'class',
#    '.'],
#   ['located',
#    'next',
#    'to',
#    'the',
#    'costco',
#    'near',
#    'woodbine',
#    '&',
#    'hwy',
#    '7',
#    '.',
#    'looks',
#    'like',
#    'lots',
#    'of',
#    'people',
#    'go',
#    'for',
#    'dim',
#    'sum',
#    'and',
#    'grocery',
#    'shopping',
#    'without',
#    'having',
#    'to',
#    'move',
#    'the',
#    'car',
#    '.',
#    'however',
#    ',',
#    'unless',
#    'you',
#    'take',
#    'advantage',
#    'of',
#    'their',
#    'early',
#    'bird',
#    'pricing',
#    '(',
#    'we',
#    'did',
#    'not',
#    ')',
#    ',',
#    'not',
#    'that',
#    'great',
#    'a',
#    'place',
#    'for',
#    'dim',
#    'sum',
#    '...',
#    'better',
#    'quality',
#    '/',
#    'price',
#    'choices',
#    'are',
#    'readily',
#    'available',
#    '.',
#    'our',
#    'party',
#    'of',
#    'four',
#    'paid',
#    '$',
#    '57',
#    'all',
#    'in',
#    'for',
#    '8',
#    'so',
#    '-',
#    'so',
#    'dim',
#    'sum',
#    'dishes',
#    'plus',
#    'a',
#    'noodle',
#    'plate',
#    '.'],
#   ['awesome',
#    'smoke',
#    'shop',
#    '!',
#    'ca',
#    "n't",
#    'say',
#    'any',
#    'bad',
#    'things',
#    'about',
#    'this',
#    'place',
#    '.',
#    'the',
#    'son',
#    'and',
#    'dad',
#    'are',
#    'really',
#    'nice',
#    'and',
#    'provide',
#    'great',
#    'customer',
#    'service',
#    '.',
#    'i',
#    'always',
#    'come',
#    'here',
#    'for',
#    'my',
#    'hookah',
#    'flavor',
#    'and',
#    'coal',
#    'and',
#    'will',
#    'continue',
#    'to',
#    'do',
#    'so',
#    '!'],
#   ['if',
#    'i',
#    'had',
#    'to',
#    'describe',
#    'this',
#    'show',
#    'in',
#    'one',
#    'word',
#    'it',
#    'would',
#    'be',
#    'energy',
#    '.',
#    'fortunately',
#    ',',
#    'i',
#    'have',
#    'enough',
#    'space',
#    'to',
#    'leave',
#    'a',
#    'full',
#    'review',
#    'here',
#    '!',
#    'jeff',
#    'civillico',
#    'has',
#    'the',
#    'most',
#    'energy',
#    'of',
#    'any',
#    'entertainer',
#    'i',
#    'have',
#    'known',
#    '.',
#    'he',
#    'spends',
#    'the',
#    'full',
#    'hour',
#    '+',
#    'show',
#    'running',
#    ',',
#    'juggling',
#    ',',
#    'and',
#    'even',
#    'unicycling',
#    ',',
#    'around',
#    'the',
#    'stage',
#    'while',
#    'being',
#    'hysterically',
#    'funny',
#    '.',
#    'he',
#    'is',
#    'not',
#    'afraid',
#    'to',
#    'take',
#    'chances',
#    'and',
#    'adds',
#    'new',
#    ',',
#    'innovative',
#    ',',
#    'tricks',
#    'and',
#    'ideas',
#    'to',
#    'his',
#    'show',
#    '(',
#    'such',
#    'as',
#    'the',
#    'go',
#    '-',
#    'pro',
#    'camera',
#    ',',
#    'his',
#    'giant',
#    'blow',
#    '-',
#    'up',
#    'set',
#    ',',
#    'a',
#    'tv',
#    'show',
#    'he',
#    'filmed',
#    'searching',
#    'for',
#    'unique',
#    'and',
#    'talented',
#    'entertainers',
#    ',',
#    'partnerships',
#    'and',
#    'promotions',
#    'of',
#    'fellow',
#    'entertainers',
#    '...',
#    ')',
#    '.',
#    'it',
#    'truly',
#    'is',
#    'a',
#    'must',
#    'see',
#    'show',
#    '...',
#    'you',
#    'never',
#    'knew',
#    'juggling',
#    'could',
#    'be',
#    'this',
#    'entertaining',
#    ',',
#    'until',
#    'you',
#    "'ve",
#    'seen',
#    'jeff',
#    "'s",
#    'show',
#    '.',
#    'i',
#    'have',
#    'seen',
#    'his',
#    'show',
#    'at',
#    'least',
#    '3',
#    'times',
#    'and',
#    'am',
#    'always',
#    'taking',
#    'family',
#    'and',
#    'friends',
#    'when',
#    'they',
#    'come',
#    'to',
#    'town',
#    '.',
#    'aside',
#    'from',
#    'the',
#    'show',
#    '-',
#    'jeff',
#    'has',
#    'a',
#    'great',
#    'talent',
#    'and',
#    'an',
#    'even',
#    'bigger',
#    'heart',
#    ',',
#    'giving',
#    'back',
#    'countless',
#    'hours',
#    'of',
#    'entertainment',
#    'and',
#    'donations',
#    '/',
#    'fundraisers',
#    'to',
#    'several',
#    'local',
#    'charities',
#    'on',
#    '-',
#    'stage',
#    'and',
#    'off',
#    '.',
#    'he',
#    'also',
#    'started',
#    'win',
#    '-',
#    'win',
#    'entertainment',
#    'to',
#    'partner',
#    'local',
#    'charities',
#    'with',
#    'celebrities',
#    'to',
#    'help',
#    'with',
#    'their',
#    'fundraising',
#    'efforts',
#    '.',
#    'he',
#    'is',
#    'highly',
#    'spoken',
#    'about',
#    'around',
#    'town',
#    'and',
#    'i',
#    'highly',
#    'encourage',
#    'you',
#    'to',
#    'support',
#    'this',
#    'great',
#    'entertainer',
#    'by',
#    'seeing',
#    'his',
#    'show',
#    '.',
#    'i',
#    'promise',
#    'you',
#    'wo',
#    "n't",
#    'be',
#    'sorry',
#    '.'],
#   ['i',
#    'ordered',
#    'the',
#    'standard',
#    'burger',
#    'and',
#    'my',
#    'husband',
#    'got',
#    'wild',
#    'boar',
#    'burger',
#    'with',
#    'fries',
#    'and',
#    'onion',
#    'rings',
#    '.',
#    'love',
#    'the',
#    'burgers',
#    'there',
#    'but',
#    'only',
#    'one',
#    'thing',
#    'is',
#    'i',
#    'should',
#    'have',
#    'ordered',
#    'medium',
#    'as',
#    'my',
#    'preference',
#    '.',
#    '(',
#    'their',
#    'red',
#    'meats',
#    'are',
#    'cooked',
#    'medium',
#    'well',
#    ')',
#    'we',
#    'definitely',
#    'want',
#    'to',
#    'go',
#    'back',
#    'to',
#    'try',
#    'elk',
#    'burger',
#    '.'],
#   ['i',
#    'always',
#    'come',
#    'here',
#    'when',
#    'i',
#    'come',
#    'to',
#    'vegas',
#    '!',
#    'instead',
#    'of',
#    'getting',
#    'a',
#    'dessert',
#    'crepe',
#    'i',
#    'got',
#    'a',
#    'savory',
#    'one',
#    'today',
#    '!',
#    'the',
#    'ham',
#    'and',
#    'cheese',
#    ',',
#    'but',
#    'i',
#    'wanted',
#    'breakfast',
#    'so',
#    'they',
#    'added',
#    'eggs',
#    'for',
#    'a',
#    '$',
#    '1.29',
#    '!',
#    'so',
#    'yummy',
#    '!',
#    '!',
#    '!'],
#   ['i',
#    'really',
#    'enjoy',
#    'coming',
#    'to',
#    'this',
#    'place',
#    '.',
#    'it',
#    'is',
#    'my',
#    'go',
#    'to',
#    'thai',
#    'place',
#    '.',
#    'their',
#    'curries',
#    'are',
#    'amazing',
#    'and',
#    'they',
#    'give',
#    'plenty',
#    'of',
#    'portions',
#    '.',
#    'as',
#    'for',
#    'their',
#    'thai',
#    'tea',
#    ',',
#    'it',
#    'is',
#    'one',
#    'of',
#    'the',
#    'best',
#    'i',
#    "'ve",
#    'had',
#    '.',
#    'i',
#    'recommend',
#    'this',
#    'place',
#    'for',
#    'sure',
#    '!'],
#   ['cliff',
#    'has',
#    'been',
#    'a',
#    'barber',
#    'for',
#    'years',
#    'so',
#    'he',
#    'knows',
#    'what',
#    'he',
#    "'s",
#    'doing',
#    '.',
#    'he',
#    'is',
#    'very',
#    'amiable',
#    '.',
#    'the',
#    'price',
#    'is',
#    'right',
#    '(',
#    '$',
#    '14',
#    ')',
#    'and',
#    'he',
#    'opens',
#    'early',
#    '(',
#    '6:30',
#    ')',
#    'so',
#    'you',
#    'can',
#    'stop',
#    'by',
#    'on',
#    'your',
#    'way',
#    'to',
#    'work',
#    '.',
#    'open',
#    'we',
#    'd',
#    '-',
#    'sat',
#    '.',
#    'great',
#    'haircut',
#    'too',
#    '.'],
#   ['the',
#    'panang',
#    'and',
#    'chicken',
#    'curry',
#    'are',
#    'delicious',
#    '.',
#    'the',
#    'dragon',
#    'eggs',
#    'are',
#    'original',
#    'and',
#    'i',
#    'like',
#    'their',
#    'green',
#    'tea',
#    '.',
#    'unfortunately',
#    'the',
#    'service',
#    'is',
#    'really',
#    'lacking',
#    '.',
#    'we',
#    'were',
#    'here',
#    'on',
#    'a',
#    'non',
#    'busy',
#    'night',
#    'and',
#    'the',
#    'table',
#    'service',
#    'was',
#    'very',
#    'slow',
#    '.',
#    'it',
#    'was',
#    'disappointing',
#    'especially',
#    'for',
#    'a',
#    'restaurant',
#    'that',
#    'made',
#    'diners',
#    'drive',
#    '-',
#    'ins',
#    'and',
#    'dives',
#    '.']]}

# %% [markdown]
# #### To be continued by Tom Sander...
